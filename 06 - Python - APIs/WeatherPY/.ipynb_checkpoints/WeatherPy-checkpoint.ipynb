# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress
import json
from datetime import datetime
import PIL as PIL

# Import API key
from api_keys import weather_api_key
API_KEY=weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
totcitydata=(len(cities))
if len(cities)>500:
    print("Okay to Proceed")
else:
    print("Need More City Data")
# Out:
# 611
# Okay to Proceed

# %%
cities
# Out:
# ['tasiilaq',
#  'butaritari',
#  'kamenskoye',
#  'bredasdorp',
#  'caarapo',
#  'rikitea',
#  'naze',
#  'hasaki',
#  'qaanaaq',
#  'ilulissat',
#  'albany',
#  'beringovskiy',
#  'kapaa',
#  'barrow',
#  'irkutsk',
#  'faanui',
#  'bluff',
#  'morros',
#  'chokurdakh',
#  'odweyne',
#  'burns lake',
#  'conde',
#  'kaeo',
#  'sitka',
#  'mahebourg',
#  'jamestown',
#  'torbay',
#  'bethel',
#  'vaini',
#  'belushya guba',
#  'mataura',
#  'manggar',
#  'new norfolk',
#  'illoqqortoormiut',
#  'punta arenas',
#  'roma',
#  'thompson',
#  'saint george',
#  'barentsburg',
#  'longyearbyen',
#  'lavrentiya',
#  'saldanha',
#  'georgetown',
#  'vostok',
#  'maceio',
#  'san cristobal',
#  'hilo',
#  'yellowknife',
#  'two hills',
#  'abong mbang',
#  'cap-aux-meules',
#  'saint-philippe',
#  'kahului',
#  'uzunovo',
#  'chernyshevskiy',
#  'ushuaia',
#  'marcona',
#  'geraldton',
#  'arraial do cabo',
#  'carnarvon',
#  'isangel',
#  'san quintin',
#  'stabat',
#  'nanortalik',
#  'ilebo',
#  'clyde river',
#  'khatanga',
#  'castro',
#  'ancud',
#  'narsaq',
#  'ahipara',
#  'busselton',
#  'atuona',
#  'cape town',
#  'vestmannaeyjar',
#  'lebu',
#  'samusu',
#  'provideniya',
#  'mys shmidta',
#  'taolanaro',
#  'hermanus',
#  'port alfred',
#  'bandipur',
#  'port-gentil',
#  'palmer',
#  'zhezkazgan',
#  'bolungarvik',
#  'bealanana',
#  'yulara',
#  'kaitangata',
#  'nevsehir',
#  'ulaangom',
#  'cuajinicuilapa',
#  'vao',
#  'talnakh',
#  'waw',
#  'axim',
#  'saint-pierre',
#  'tarauaca',
#  'codrington',
#  'ostroh',
#  'uray',
#  'thinadhoo',
#  'staryy nadym',
#  'mar del plata',
#  'bosaso',
#  'road town',
#  'makakilo city',
#  'pevek',
#  'pasighat',
#  'comodoro rivadavia',
#  'huangchuan',
#  'port macquarie',
#  'kenai',
#  'kodiak',
#  'hurghada',
#  'brufut',
#  'bagrami',
#  'kruisfontein',
#  'hobart',
#  'shiraz',
#  'te anau',
#  'kostalexis',
#  'ostrovnoy',
#  'nago',
#  'dukat',
#  'valparaiso',
#  'kusk',
#  'benguela',
#  'port elizabeth',
#  'iquitos',
#  'puerto palomas',
#  'santo domingo',
#  'vila franca do campo',
#  'mont-de-marsan',
#  'ponta do sol',
#  'aktash',
#  'kiama',
#  'tuktoyaktuk',
#  'male',
#  'harstad',
#  'pangnirtung',
#  'mount isa',
#  'tiksi',
#  'dinsor',
#  'saskylakh',
#  'puerto ayora',
#  'gaya',
#  'cherskiy',
#  'terrace bay',
#  'cagayan de tawi-tawi',
#  'nome',
#  'murgab',
#  'attawapiskat',
#  'jensen beach',
#  'cabo san lucas',
#  'fairbanks',
#  'taoudenni',
#  'husavik',
#  'bambui',
#  'takoradi',
#  'gat',
#  'avarua',
#  'esperance',
#  'korla',
#  'palabuhanratu',
#  'ostersund',
#  'noumea',
#  'agropoli',
#  'oga',
#  'tsihombe',
#  'dawlatabad',
#  'watari',
#  'atar',
#  'biak',
#  'portland',
#  'dir',
#  'dhankuta',
#  'ust-nera',
#  'miles city',
#  'haines junction',
#  'westport',
#  'ndele',
#  'broome',
#  'nikolskoye',
#  'margate',
#  'wadi musa',
#  'bulgan',
#  'kamaishi',
#  'kattivakkam',
#  'garissa',
#  'iqaluit',
#  'mamallapuram',
#  'touho',
#  'hami',
#  'ngukurr',
#  'faya',
#  'jishu',
#  'yen bai',
#  'prince rupert',
#  'solvychegodsk',
#  'san rafael',
#  'aitape',
#  'verkhnevilyuysk',
#  'deputatskiy',
#  'northam',
#  'dunedin',
#  'donetsk',
#  'katsuura',
#  'otorohanga',
#  'senj',
#  'tiznit',
#  'alenquer',
#  'dikson',
#  'norman wells',
#  'san ramon',
#  'severo-kurilsk',
#  'santa rosa',
#  'cidreira',
#  'buraydah',
#  'barcelos',
#  'choctaw',
#  'tabiauea',
#  'muchkapskiy',
#  'salinopolis',
#  'mocuba',
#  'guanica',
#  'rodez',
#  'howard springs',
#  'kuju',
#  'cockburn town',
#  'hofn',
#  'vega de alatorre',
#  'nguiu',
#  'lincoln',
#  'nizhneyansk',
#  'east london',
#  'fortuna',
#  'bardiyah',
#  'tuatapere',
#  'east longmeadow',
#  'erenhot',
#  'mogok',
#  'khandyga',
#  'airai',
#  'la peca',
#  'pacific grove',
#  'pauini',
#  'bayir',
#  'arman',
#  'keskin',
#  'souillac',
#  'sosnovka',
#  'kopayhorod',
#  'manta',
#  'ambulu',
#  'enshi',
#  'nanchang',
#  'sumbawa',
#  'denham springs',
#  'lata',
#  'roald',
#  'ribeira grande',
#  'chanika',
#  'tungkang',
#  'ulaanbaatar',
#  'vardo',
#  'sisimiut',
#  'batemans bay',
#  'turangi',
#  'amderma',
#  'bengkulu',
#  'chagda',
#  'buala',
#  'sao joao da barra',
#  'la ronge',
#  'tecpan',
#  'the valley',
#  'zyryanka',
#  'leningradskiy',
#  'ust-ishim',
#  'japura',
#  'znamenskoye',
#  'port hardy',
#  'tura',
#  'victoria',
#  'kegayli',
#  'macas',
#  'bialystok',
#  'calbuco',
#  'grand river south east',
#  'mahina',
#  'cayenne',
#  'ixtapa',
#  'eldikan',
#  'udachnyy',
#  'portree',
#  'rocha',
#  'sentyabrskiy',
#  'hisua',
#  'livingstonia',
#  'takab',
#  'kapit',
#  'paamiut',
#  'kulhudhuffushi',
#  'fort nelson',
#  'galchino',
#  'obihiro',
#  'bathsheba',
#  'kem',
#  'tromso',
#  'mugumu',
#  'dingle',
#  'saint andrews',
#  'sorland',
#  'peterhead',
#  'ngunguru',
#  'pokrovsk-uralskiy',
#  'mayahi',
#  'itarema',
#  'yazykovo',
#  'batagay',
#  'yarqa',
#  'sulangan',
#  'mogadishu',
#  'kushima',
#  'santa rita',
#  'elko',
#  'lompoc',
#  'longhua',
#  'aflu',
#  'sambava',
#  'yar-sale',
#  'mogzon',
#  'sao filipe',
#  'muscat',
#  'vila velha',
#  'banda aceh',
#  'honningsvag',
#  'kaohsiung',
#  'didi lilo',
#  'adrar',
#  'torrington',
#  'meyungs',
#  'koumac',
#  'san pedro de macoris',
#  'bilibino',
#  'alofi',
#  'gushikawa',
#  'daru',
#  'pisco',
#  'merauke',
#  'changji',
#  'marsa matruh',
#  'marzuq',
#  'kailua',
#  'bandar-e lengeh',
#  'talara',
#  'hithadhoo',
#  'diapaga',
#  'pingliang',
#  'fort saint james',
#  'vaitupu',
#  'tamiahua',
#  'havre-saint-pierre',
#  'chernushka',
#  'kadoma',
#  'yerbogachen',
#  'port lincoln',
#  'beyneu',
#  'aljezur',
#  'kambi',
#  'saquena',
#  'huarmey',
#  'taungdwingyi',
#  'yangambi',
#  'kavieng',
#  'arrecife',
#  'antofagasta',
#  'general pico',
#  'bereda',
#  'chuy',
#  'vaxjo',
#  'woodward',
#  'sao felix do xingu',
#  'mayumba',
#  'guerrero negro',
#  'visaginas',
#  'boddam',
#  'bonavista',
#  'navalmoral de la mata',
#  'coos bay',
#  'batouri',
#  'edea',
#  'ust-shonosha',
#  'havoysund',
#  'nacala',
#  'port-cartier',
#  'xiuyan',
#  'kavaratti',
#  'halifax',
#  'nyurba',
#  'port blair',
#  'wanning',
#  'bur gabo',
#  'karratha',
#  'oranjemund',
#  'mangan',
#  'mrirt',
#  'tonj',
#  'sorvag',
#  'sovetskiy',
#  'fort saint john',
#  'katangli',
#  'aklavik',
#  'takahata',
#  'kemijarvi',
#  'sabla',
#  'kutum',
#  'redwater',
#  'tobol',
#  'srandakan',
#  'goderich',
#  'moose factory',
#  'utiroa',
#  'provatas',
#  'worland',
#  'haljala',
#  'xai-xai',
#  'tasbuget',
#  'bo',
#  'olinda',
#  'evensk',
#  'hamilton',
#  'denizli',
#  'forest lake',
#  'dzerzhinsk',
#  'sorong',
#  'saint-francois',
#  'kiruna',
#  'sawakin',
#  'namangan',
#  'nebolchi',
#  'baykit',
#  'ola',
#  'aloleng',
#  'saint-augustin',
#  'osoyoos',
#  'zarand',
#  'upernavik',
#  'chongwe',
#  'chekmagush',
#  'coihaique',
#  'ksenyevka',
#  'albert lea',
#  'awbari',
#  'sinkat',
#  'toftir',
#  'alotau',
#  'labutta',
#  'manitouwadge',
#  'velikiy ustyug',
#  'ucluelet',
#  'honiara',
#  'joao camara',
#  'mgandu',
#  'luderitz',
#  'turukhansk',
#  'vagur',
#  'marawi',
#  'tivaouane',
#  'kangaatsiaq',
#  'peno',
#  'cabra',
#  'newport beach',
#  'belyy yar',
#  'koshurnikovo',
#  'tomaszow mazowiecki',
#  'kabare',
#  'edd',
#  'ornskoldsvik',
#  'newport',
#  'qaqortoq',
#  'quatre cocos',
#  'nador',
#  'rio grande',
#  'yatou',
#  'san patricio',
#  'kanigoro',
#  'coquimbo',
#  'sobolevo',
#  'srednekolymsk',
#  'padang',
#  'bargal',
#  'tynda',
#  'bodoco',
#  'villazon',
#  'basco',
#  'mindelo',
#  'opuwo',
#  'anori',
#  'nabire',
#  'xilagani',
#  'maumere',
#  'machiques',
#  'atasu',
#  'singojuruh',
#  'pangai',
#  'tumannyy',
#  'formoso do araguaia',
#  'panorama',
#  'burica',
#  'mahanoro',
#  'los llanos de aridane',
#  'clinton',
#  'klaksvik',
#  'verkhoyansk',
#  'manadhoo',
#  'seoul',
#  'gladstone',
#  'hobyo',
#  'ashtian',
#  'tarko-sale',
#  'borgustanskaya',
#  'belaya gora',
#  'ketchikan',
#  'kununurra',
#  'alyangula',
#  'masasi',
#  'binga',
#  'pokosnoye',
#  'adilcevaz',
#  'flinders',
#  'puerto ayacucho',
#  'north branch',
#  'tautira',
#  'tigil',
#  'namibe',
#  'hailar',
#  'khao wong',
#  'nsanje',
#  'baneh',
#  'aykhal',
#  'wonthaggi',
#  'zachagansk',
#  'manali',
#  'falun',
#  'constitucion',
#  'fredericksburg',
#  'krasnoselkup',
#  'bure',
#  'emerald',
#  'jutai',
#  'usakos',
#  'trofors',
#  'pascagoula',
#  'vrangel',
#  'babanusah',
#  'savannah bight',
#  'carahue',
#  'lazaro cardenas',
#  'mansa',
#  'mangaratiba',
#  'avera',
#  'gazanjyk',
#  'hendrina',
#  'qiongshan',
#  'laguna',
#  'pombas',
#  'sterling',
#  'carballo',
#  'nouadhibou',
#  'camana',
#  'trelew',
#  'santa maria',
#  'pont-audemer',
#  'zverinogolovskoye',
#  'puerto escondido',
#  'lahuachaca',
#  'pontes e lacerda',
#  'wolgast',
#  'necochea',
#  'uchaly',
#  'along',
#  'amarante',
#  'birao',
#  'karpogory',
#  'poyarkovo',
#  'artigas',
#  'meulaboh',
#  'kupang',
#  'omutninsk',
#  'ngama',
#  'tual',
#  'yenagoa',
#  'bambous virieux',
#  'lahat',
#  'itapirapua',
#  'praya',
#  'galveston',
#  'katherine',
#  'shchelyayur',
#  'severnoye',
#  'mantua',
#  'mitsamiouli',
#  'rio gallegos',
#  'muzhi',
#  'menongue',
#  'ous',
#  'tias',
#  'dologon']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_KEY
response = requests.get(f"{url}&q={city}").json() 
response
# Out:
# {'coord': {'lon': -69.3632, 'lat': 77.484},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 0.77,
#   'feels_like': -11.45,
#   'temp_min': 0.77,
#   'temp_max': 0.77,
#   'pressure': 1023,
#   'humidity': 64,
#   'sea_level': 1023,
#   'grnd_level': 1019},
#  'visibility': 10000,
#  'wind': {'speed': 6.4, 'deg': 22, 'gust': 6.35},
#  'clouds': {'all': 3},
#  'dt': 1618532075,
#  'sys': {'country': 'GL', 'sunrise': 1618468934, 'sunset': 1618540329},
#  'timezone': -10800,
#  'id': 3831208,
#  'name': 'Qaanaaq',
#  'cod': 200}

# %%
city
# Out:
# 'qaanaaq'

# %%
#Json weather check for each city and print log
city_name = []
clouds = []
country = []
wind_speed = []
date = []
latitude = []
longitude = []
max_temp = []
humidity = []

counter=1
print(f"Weather Data Processing Initialization")
print(f"______________________________________")
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_KEY
for city in cities:
    try:
        response=requests.get(f"{url}&q={city}").json()
        city_name.append(response["name"])
        clouds.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {counter} of {totcitydata} | {city_record}")
        counter=counter+1

# If no record found "skip" to next call
    except:
        print("City not found. Skipping this location...")
    continue
# Out:
# Weather Data Processing Initialization
# ______________________________________
# Processing Record 1 of 611 | Tasiilaq
# Processing Record 2 of 611 | Butaritari
# City not found. Skipping this location...
# Processing Record 3 of 611 | Bredasdorp
# Processing Record 4 of 611 | Caarapó
# Processing Record 5 of 611 | Rikitea
# Processing Record 6 of 611 | Naze
# Processing Record 7 of 611 | Hasaki
# Processing Record 8 of 611 | Qaanaaq
# Processing Record 9 of 611 | Ilulissat
# Processing Record 10 of 611 | Albany
# Processing Record 11 of 611 | Beringovskiy
# Processing Record 12 of 611 | Kapaa
# Processing Record 13 of 611 | Barrow
# Processing Record 14 of 611 | Irkutsk
# Processing Record 15 of 611 | Faanui
# Processing Record 16 of 611 | Bluff
# Processing Record 17 of 611 | Morros
# Processing Record 18 of 611 | Chokurdakh
# Processing Record 19 of 611 | Oodweyne
# Processing Record 20 of 611 | Burns Lake
# Processing Record 21 of 611 | Conde
# Processing Record 22 of 611 | Kaeo
# Processing Record 23 of 611 | Sitka
# Processing Record 24 of 611 | Mahébourg
# Processing Record 25 of 611 | Jamestown
# Processing Record 26 of 611 | Torbay
# Processing Record 27 of 611 | Bethel
# Processing Record 28 of 611 | Vaini
# City not found. Skipping this location...
# Processing Record 29 of 611 | Mataura
# Processing Record 30 of 611 | Manggar
# Processing Record 31 of 611 | New Norfolk
# City not found. Skipping this location...
# Processing Record 32 of 611 | Punta Arenas
# Processing Record 33 of 611 | Rome
# Processing Record 34 of 611 | Thompson
# Processing Record 35 of 611 | Saint George
# City not found. Skipping this location...
# Processing Record 36 of 611 | Longyearbyen
# Processing Record 37 of 611 | Lavrentiya
# Processing Record 38 of 611 | Saldanha
# Processing Record 39 of 611 | George Town
# Processing Record 40 of 611 | Vostok
# Processing Record 41 of 611 | Maceió
# Processing Record 42 of 611 | San Cristobal
# Processing Record 43 of 611 | Hilo
# Processing Record 44 of 611 | Yellowknife
# Processing Record 45 of 611 | Two Hills
# Processing Record 46 of 611 | Abong Mbang
# Processing Record 47 of 611 | Cap-aux-Meules
# Processing Record 48 of 611 | Saint-Philippe
# Processing Record 49 of 611 | Kahului
# Processing Record 50 of 611 | Uzunovo
# Processing Record 51 of 611 | Chernyshevskiy
# Processing Record 52 of 611 | Ushuaia
# City not found. Skipping this location...
# Processing Record 53 of 611 | Geraldton
# Processing Record 54 of 611 | Arraial do Cabo
# Processing Record 55 of 611 | Carnarvon
# Processing Record 56 of 611 | Isangel
# Processing Record 57 of 611 | San Quintín
# Processing Record 58 of 611 | Stabat
# Processing Record 59 of 611 | Nanortalik
# Processing Record 60 of 611 | Ilebo
# Processing Record 61 of 611 | Clyde River
# Processing Record 62 of 611 | Khatanga
# Processing Record 63 of 611 | Castro
# Processing Record 64 of 611 | Ancud
# Processing Record 65 of 611 | Narsaq
# Processing Record 66 of 611 | Ahipara
# Processing Record 67 of 611 | Busselton
# Processing Record 68 of 611 | Atuona
# Processing Record 69 of 611 | Cape Town
# Processing Record 70 of 611 | Vestmannaeyjar
# Processing Record 71 of 611 | Lebu
# City not found. Skipping this location...
# Processing Record 72 of 611 | Provideniya
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 73 of 611 | Hermanus
# Processing Record 74 of 611 | Port Alfred
# Processing Record 75 of 611 | Bandi̇̄pur
# Processing Record 76 of 611 | Port-Gentil
# Processing Record 77 of 611 | Palmer
# Processing Record 78 of 611 | Zhezkazgan
# City not found. Skipping this location...
# Processing Record 79 of 611 | Bealanana
# Processing Record 80 of 611 | Yulara
# Processing Record 81 of 611 | Kaitangata
# Processing Record 82 of 611 | Nevşehir
# Processing Record 83 of 611 | Ulaangom
# Processing Record 84 of 611 | Cuajinicuilapa
# Processing Record 85 of 611 | Vao
# Processing Record 86 of 611 | Talnakh
# Processing Record 87 of 611 | Wau
# Processing Record 88 of 611 | Esim
# Processing Record 89 of 611 | Saint-Pierre
# Processing Record 90 of 611 | Tarauacá
# Processing Record 91 of 611 | Codrington
# Processing Record 92 of 611 | Ostroh
# Processing Record 93 of 611 | Uray
# Processing Record 94 of 611 | Thinadhoo
# Processing Record 95 of 611 | Staryy Nadym
# Processing Record 96 of 611 | Mar del Plata
# Processing Record 97 of 611 | Bosaso
# Processing Record 98 of 611 | Road Town
# Processing Record 99 of 611 | Makakilo City
# Processing Record 100 of 611 | Pevek
# Processing Record 101 of 611 | Pāsighāt
# Processing Record 102 of 611 | Comodoro Rivadavia
# Processing Record 103 of 611 | Dingcheng
# Processing Record 104 of 611 | Port Macquarie
# Processing Record 105 of 611 | Kenai
# Processing Record 106 of 611 | Saint Paul Harbor
# Processing Record 107 of 611 | Hurghada
# Processing Record 108 of 611 | Brufut
# Processing Record 109 of 611 | Bagrāmī
# Processing Record 110 of 611 | Kruisfontein
# Processing Record 111 of 611 | Hobart
# Processing Record 112 of 611 | Shiraz
# Processing Record 113 of 611 | Te Anau
# Processing Record 114 of 611 | Kostalexis
# Processing Record 115 of 611 | Ostrovnoy
# Processing Record 116 of 611 | Nago
# Processing Record 117 of 611 | Dukat
# Processing Record 118 of 611 | Valparaíso
# City not found. Skipping this location...
# Processing Record 119 of 611 | Benguela
# Processing Record 120 of 611 | Port Elizabeth
# Processing Record 121 of 611 | Iquitos
# Processing Record 122 of 611 | Puerto Palomas
# Processing Record 123 of 611 | Santo Domingo
# Processing Record 124 of 611 | Vila Franca do Campo
# Processing Record 125 of 611 | Arrondissement de Mont-de-Marsan
# Processing Record 126 of 611 | Ponta do Sol
# Processing Record 127 of 611 | Aktash
# Processing Record 128 of 611 | Kiama
# Processing Record 129 of 611 | Tuktoyaktuk
# Processing Record 130 of 611 | Malé
# Processing Record 131 of 611 | Harstad
# Processing Record 132 of 611 | Pangnirtung
# Processing Record 133 of 611 | Mount Isa
# Processing Record 134 of 611 | Tiksi
# City not found. Skipping this location...
# Processing Record 135 of 611 | Saskylakh
# Processing Record 136 of 611 | Puerto Ayora
# Processing Record 137 of 611 | Gaya
# Processing Record 138 of 611 | Cherskiy
# Processing Record 139 of 611 | Terrace Bay
# City not found. Skipping this location...
# Processing Record 140 of 611 | Nome
# Processing Record 141 of 611 | Murgab
# City not found. Skipping this location...
# Processing Record 142 of 611 | Jensen Beach
# Processing Record 143 of 611 | Cabo San Lucas
# Processing Record 144 of 611 | Fairbanks
# Processing Record 145 of 611 | Taoudenni
# Processing Record 146 of 611 | Husavik
# Processing Record 147 of 611 | Bambuí
# Processing Record 148 of 611 | Takoradze
# Processing Record 149 of 611 | Kiryat Gat
# Processing Record 150 of 611 | Avarua
# Processing Record 151 of 611 | Esperance
# Processing Record 152 of 611 | Korla
# City not found. Skipping this location...
# Processing Record 153 of 611 | Östersund
# Processing Record 154 of 611 | Noumea
# Processing Record 155 of 611 | Agropoli
# Processing Record 156 of 611 | Oga
# City not found. Skipping this location...
# Processing Record 157 of 611 | Dawlatabad
# Processing Record 158 of 611 | Watari
# Processing Record 159 of 611 | Atar
# Processing Record 160 of 611 | Biak
# Processing Record 161 of 611 | Portland
# Processing Record 162 of 611 | Dīr
# Processing Record 163 of 611 | Dhankutā
# Processing Record 164 of 611 | Ust-Nera
# Processing Record 165 of 611 | Miles City
# Processing Record 166 of 611 | Haines Junction
# Processing Record 167 of 611 | Westport
# Processing Record 168 of 611 | Ndélé
# Processing Record 169 of 611 | Broome
# Processing Record 170 of 611 | Nikolskoye
# Processing Record 171 of 611 | Margate
# Processing Record 172 of 611 | Petra
# Processing Record 173 of 611 | Bulgan
# Processing Record 174 of 611 | Kamaishi
# Processing Record 175 of 611 | Kattivākkam
# Processing Record 176 of 611 | Garissa
# Processing Record 177 of 611 | Iqaluit
# Processing Record 178 of 611 | Mahabalipuram
# Processing Record 179 of 611 | Touho
# Processing Record 180 of 611 | Kumul
# City not found. Skipping this location...
# Processing Record 181 of 611 | Faya
# Processing Record 182 of 611 | Jishu
# Processing Record 183 of 611 | Yen Bai
# Processing Record 184 of 611 | Prince Rupert
# Processing Record 185 of 611 | Sol'vychegodsk
# Processing Record 186 of 611 | San Rafael
# Processing Record 187 of 611 | Aitape
# Processing Record 188 of 611 | Verkhnevilyuysk
# Processing Record 189 of 611 | Deputatsky
# Processing Record 190 of 611 | Northam
# Processing Record 191 of 611 | Dunedin
# Processing Record 192 of 611 | Donetsk
# Processing Record 193 of 611 | Katsuura
# Processing Record 194 of 611 | Otorohanga
# Processing Record 195 of 611 | Senj
# Processing Record 196 of 611 | Tiznit Province
# Processing Record 197 of 611 | Alenquer
# Processing Record 198 of 611 | Dikson
# Processing Record 199 of 611 | Norman Wells
# Processing Record 200 of 611 | San Ramon
# Processing Record 201 of 611 | Severo-Kuril'sk
# Processing Record 202 of 611 | Santa Rosa
# Processing Record 203 of 611 | Cidreira
# Processing Record 204 of 611 | Buraidah
# Processing Record 205 of 611 | Barcelos
# Processing Record 206 of 611 | Choctaw
# City not found. Skipping this location...
# Processing Record 207 of 611 | Muchkapskiy
# Processing Record 208 of 611 | Salinópolis
# Processing Record 209 of 611 | Mocuba
# Processing Record 210 of 611 | Guánica
# Processing Record 211 of 611 | Arrondissement de Rodez
# Processing Record 212 of 611 | Howard Springs
# Processing Record 213 of 611 | Kuju
# Processing Record 214 of 611 | Cockburn Town
# Processing Record 215 of 611 | Hofn
# Processing Record 216 of 611 | Vega de Alatorre
# City not found. Skipping this location...
# Processing Record 217 of 611 | Lincoln
# City not found. Skipping this location...
# Processing Record 218 of 611 | East London
# Processing Record 219 of 611 | Fortuna
# Processing Record 220 of 611 | Al Bardīyah
# Processing Record 221 of 611 | Tuatapere
# Processing Record 222 of 611 | East Longmeadow
# Processing Record 223 of 611 | Erenhot
# Processing Record 224 of 611 | Mogok
# Processing Record 225 of 611 | Khandyga
# Processing Record 226 of 611 | Airai
# Processing Record 227 of 611 | La Peca
# Processing Record 228 of 611 | Pacific Grove
# Processing Record 229 of 611 | Pauini
# Processing Record 230 of 611 | Bayir
# Processing Record 231 of 611 | Arman'
# Processing Record 232 of 611 | Keskin
# Processing Record 233 of 611 | Souillac
# Processing Record 234 of 611 | Sosnovka
# Processing Record 235 of 611 | Kopayhorod
# Processing Record 236 of 611 | Manta
# Processing Record 237 of 611 | Ambulu
# Processing Record 238 of 611 | Enshi
# Processing Record 239 of 611 | Nanchang
# City not found. Skipping this location...
# Processing Record 240 of 611 | Denham Springs
# Processing Record 241 of 611 | Lata
# Processing Record 242 of 611 | Roald
# Processing Record 243 of 611 | Ribeira Grande
# Processing Record 244 of 611 | Chanika
# City not found. Skipping this location...
# Processing Record 245 of 611 | Ulaanbaatar
# Processing Record 246 of 611 | Vardø
# Processing Record 247 of 611 | Sisimiut
# Processing Record 248 of 611 | Batemans Bay
# Processing Record 249 of 611 | Turangi
# City not found. Skipping this location...
# Processing Record 250 of 611 | Bengkulu
# City not found. Skipping this location...
# Processing Record 251 of 611 | Buala
# Processing Record 252 of 611 | São João da Barra
# Processing Record 253 of 611 | La Ronge
# Processing Record 254 of 611 | Tecpan
# Processing Record 255 of 611 | The Valley
# Processing Record 256 of 611 | Zyryanka
# Processing Record 257 of 611 | Leningradskiy
# Processing Record 258 of 611 | Ust'-Ishim
# Processing Record 259 of 611 | Japura
# Processing Record 260 of 611 | Znamenskoye
# Processing Record 261 of 611 | Port Hardy
# Processing Record 262 of 611 | Tura
# Processing Record 263 of 611 | Hong Kong
# City not found. Skipping this location...
# Processing Record 264 of 611 | Macas
# Processing Record 265 of 611 | Białystok
# Processing Record 266 of 611 | Calbuco
# City not found. Skipping this location...
# Processing Record 267 of 611 | Mahina
# Processing Record 268 of 611 | Cayenne
# Processing Record 269 of 611 | Ixtapa
# City not found. Skipping this location...
# Processing Record 270 of 611 | Udachny
# Processing Record 271 of 611 | Portree
# Processing Record 272 of 611 | Rocha
# City not found. Skipping this location...
# Processing Record 273 of 611 | Hisuā
# Processing Record 274 of 611 | Livingstonia
# Processing Record 275 of 611 | Takāb
# Processing Record 276 of 611 | Kapit
# Processing Record 277 of 611 | Paamiut
# Processing Record 278 of 611 | Kulhudhuffushi
# Processing Record 279 of 611 | Fort Nelson
# City not found. Skipping this location...
# Processing Record 280 of 611 | Obihiro
# Processing Record 281 of 611 | Bathsheba
# Processing Record 282 of 611 | Kem'
# Processing Record 283 of 611 | Tromsø
# Processing Record 284 of 611 | Mugumu
# Processing Record 285 of 611 | Dingle
# Processing Record 286 of 611 | Saint Andrews
# Processing Record 287 of 611 | Sørland
# Processing Record 288 of 611 | Peterhead
# Processing Record 289 of 611 | Ngunguru
# City not found. Skipping this location...
# Processing Record 290 of 611 | Mayahi
# Processing Record 291 of 611 | Itarema
# Processing Record 292 of 611 | Yazykovo
# Processing Record 293 of 611 | Batagay
# Processing Record 294 of 611 | Yarqā
# Processing Record 295 of 611 | Sulangan
# Processing Record 296 of 611 | Mogadishu
# Processing Record 297 of 611 | Kushima
# Processing Record 298 of 611 | Santa Rita
# Processing Record 299 of 611 | Elko
# Processing Record 300 of 611 | Lompoc
# Processing Record 301 of 611 | Longhua
# City not found. Skipping this location...
# Processing Record 302 of 611 | Sambava
# Processing Record 303 of 611 | Yar-Sale
# Processing Record 304 of 611 | Mogzon
# Processing Record 305 of 611 | São Filipe
# Processing Record 306 of 611 | Muscat
# Processing Record 307 of 611 | Vila Velha
# Processing Record 308 of 611 | Banda Aceh
# Processing Record 309 of 611 | Honningsvåg
# Processing Record 310 of 611 | Kaohsiung City
# Processing Record 311 of 611 | Didi Lilo
# Processing Record 312 of 611 | Adrar
# Processing Record 313 of 611 | Torrington
# City not found. Skipping this location...
# Processing Record 314 of 611 | Koumac
# Processing Record 315 of 611 | San Pedro de Macorís
# Processing Record 316 of 611 | Bilibino
# Processing Record 317 of 611 | Alofi
# Processing Record 318 of 611 | Gushikawa
# Processing Record 319 of 611 | Daru
# Processing Record 320 of 611 | Pisco
# Processing Record 321 of 611 | Merauke
# Processing Record 322 of 611 | Changji
# Processing Record 323 of 611 | Marsá Maţrūḩ
# Processing Record 324 of 611 | Marzuq
# Processing Record 325 of 611 | Kailua
# Processing Record 326 of 611 | Bandar-e Lengeh
# Processing Record 327 of 611 | Talara
# Processing Record 328 of 611 | Hithadhoo
# Processing Record 329 of 611 | Diapaga
# Processing Record 330 of 611 | Pingliang
# Processing Record 331 of 611 | Fort Saint James
# City not found. Skipping this location...
# Processing Record 332 of 611 | Tamiahua
# Processing Record 333 of 611 | Havre-St-Pierre
# Processing Record 334 of 611 | Chernushka
# Processing Record 335 of 611 | Kadoma
# Processing Record 336 of 611 | Yerbogachën
# Processing Record 337 of 611 | Port Lincoln
# Processing Record 338 of 611 | Beyneu
# Processing Record 339 of 611 | Aljezur
# Processing Record 340 of 611 | Kambi
# Processing Record 341 of 611 | Saquena
# Processing Record 342 of 611 | Huarmey
# Processing Record 343 of 611 | Taungdwingyi
# Processing Record 344 of 611 | Yangambi
# Processing Record 345 of 611 | Kavieng
# Processing Record 346 of 611 | Arrecife
# Processing Record 347 of 611 | Antofagasta
# Processing Record 348 of 611 | General Pico
# Processing Record 349 of 611 | Bereda
# Processing Record 350 of 611 | Chui
# Processing Record 351 of 611 | Vaxjo
# Processing Record 352 of 611 | Woodward
# Processing Record 353 of 611 | São Félix do Xingu
# Processing Record 354 of 611 | Mayumba
# Processing Record 355 of 611 | Guerrero Negro
# Processing Record 356 of 611 | Visaginas
# Processing Record 357 of 611 | Boddam
# Processing Record 358 of 611 | Bonavista
# Processing Record 359 of 611 | Navalmoral de la Mata
# Processing Record 360 of 611 | Coos Bay
# Processing Record 361 of 611 | Batouri
# Processing Record 362 of 611 | Edéa
# Processing Record 363 of 611 | Ust'-Shonosha
# Processing Record 364 of 611 | Havøysund
# Processing Record 365 of 611 | Nacala
# Processing Record 366 of 611 | Port-Cartier
# Processing Record 367 of 611 | Xiuyan
# Processing Record 368 of 611 | Kavaratti
# Processing Record 369 of 611 | Halifax
# Processing Record 370 of 611 | Nyurba
# Processing Record 371 of 611 | Port Blair
# Processing Record 372 of 611 | Wanning
# City not found. Skipping this location...
# Processing Record 373 of 611 | Karratha
# Processing Record 374 of 611 | Oranjemund
# Processing Record 375 of 611 | Mangan
# City not found. Skipping this location...
# Processing Record 376 of 611 | Tonj
# City not found. Skipping this location...
# Processing Record 377 of 611 | Sovetskiy
# City not found. Skipping this location...
# Processing Record 378 of 611 | Katangli
# Processing Record 379 of 611 | Aklavik
# Processing Record 380 of 611 | Takahata
# Processing Record 381 of 611 | Kemijärvi
# Processing Record 382 of 611 | Sabla
# Processing Record 383 of 611 | Kutum
# Processing Record 384 of 611 | Redwater
# Processing Record 385 of 611 | Tobol
# Processing Record 386 of 611 | Srandakan
# Processing Record 387 of 611 | Goderich
# Processing Record 388 of 611 | Moose Factory
# City not found. Skipping this location...
# Processing Record 389 of 611 | Provatas
# Processing Record 390 of 611 | Worland

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data=pd.DataFrame({"City":city_name,
                        "Cloudiness":clouds,
                        "Country":country,
                        "Date":date,
                        "Humidity":humidity,
                        "Lat":latitude,
                        "Lng":longitude,
                        "Max Temp":max_temp,
                        "Wind Speed":wind_speed})
city_data
# Out:
#                City  Cloudiness Country        Date  Humidity      Lat  \
# 0         Cape Town           0      ZA  1618527653        68 -33.9258
# 1           Aklavik          75      CA  1618527763        68  68.2191
# 2            Hobart          40      AU  1618527623        58 -42.8794
# 3     Pacific Grove           1      US  1618528298        51  36.6177
# 4              Lebu          27      CL  1618527735        87 -37.6167
# ..              ...         ...     ...         ...       ...      ...
# 544        Manthani           0      IN  1618528515        67  18.6500
# 545  Port Macquarie          46      AU  1618528515        53 -31.4333
# 546          Iseyin          98      NG  1618528516        79   7.9667
# 547          Kenora          75      CA  1618528516        46  49.8167
# 548            Soyo         100      AO  1618528516        83  -6.1349
#
#           Lng  Max Temp  Wind Speed
# 0     18.4232     66.99        8.05
# 1   -135.0107     23.00        9.22
# 2    147.3294     53.01       13.80
# 3   -121.9166     62.60       11.50
# 4    -73.6500     55.08       11.54
# ..        ...       ...         ...
# 544   79.6667     78.96        4.25
# 545  152.9167     72.00        1.99
# 546    3.6000     74.32        7.14
# 547  -94.4337     48.20       11.50
# 548   12.3689     80.10        5.08
#
# [549 rows x 9 columns]

# %%
city_data["Humidity"].max()
# Out:
# 100

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data.count()
# Out:
# City          549
# Cloudiness    549
# Country       549
# Date          549
# Humidity      549
# Lat           549
# Lng           549
# Max Temp      549
# Wind Speed    549
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
#convert unix timestamp to date time - pandas.pydata.org time series/date functionality
city_data["Date"]=pd.to_datetime(city_data["Date"],unit="s")
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=city_data[["City","Lat","Lng","Max Temp","Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]]
clean_sort=clean_city_data.sort_values(by='City',ascending=True).reset_index(drop=True)
clean_sort
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Abu Dhabi  24.4667   54.3667     80.60        57           0
# 1            Abu Samrah  35.3029   37.1841     59.92        51          24
# 2    Acapulco de Juárez  16.8634  -99.8901     82.40        74          75
# 3              Adelaide -34.9333  138.6000     59.00        82          20
# 4                  Aden  12.7794   45.0367     80.40        74           0
# ..                  ...      ...       ...       ...       ...         ...
# 544              Zarand  30.8127   56.5640     58.84        48           1
# 545               Zarya  55.7553   38.0958     51.80        66           0
# 546          Zhangaözen  43.3000   52.8000     53.62        61          43
# 547            Zhigansk  66.7697  123.3711     15.35        96          97
# 548           ‘Āhuimanu  21.4447 -157.8378     82.40        65          20
#
#      Wind Speed Country                Date
# 0          8.05      AE 2021-04-15 23:13:31
# 1          0.76      SY 2021-04-15 23:03:59
# 2         10.36      MX 2021-04-15 23:10:07
# 3          3.44      AU 2021-04-15 23:12:07
# 4         17.29      YE 2021-04-15 23:07:04
# ..          ...     ...                 ...
# 544        3.36      IR 2021-04-15 23:07:13
# 545       13.42      RU 2021-04-15 23:14:54
# 546        9.19      KZ 2021-04-15 23:12:37
# 547       13.89      RU 2021-04-15 23:03:03
# 548       11.50      US 2021-04-15 23:15:10
#
# [549 rows x 9 columns]

# %%
clean_sort=clean_sort.rename(columns={"Max Temp":"Max Temp ˚F"})
clean_sort
clean_sort.to_csv('output_data/cities.csv',index=True,header=True)
datadate=((clean_sort.iloc[0,8]))
chartdate=(datadate.strftime("%b %d, %Y"))

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Max Temp ˚F"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Max. Temperature  "+"("+chartdate+")")
plt.ylabel("Max. Temperature (˚F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvsmaxtemp.png")
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Humidity"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Humidity (%)  "+"("+chartdate+")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvshumidity.png")
plt.savefig("output_data/Fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Cloudiness"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Cloudiness (%)  "+"("+chartdate+")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvscloud.png")
plt.savefig("output_data/Fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Wind Speed"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Wind Speed  "+"("+chartdate+")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvsmaxtemp.png")
plt.savefig("output_data/Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northhem=clean_sort[clean_sort['Lat']>=0]
southhem=clean_sort[clean_sort['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northhem['Lat']
y_values = northhem['Max Temp ˚F']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.scatter(northhem["Lat"],northhem["Max Temp ˚F"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("Northern Latitude vs. Max. Temperature  "+"("+chartdate+")")
plt.ylabel("Max. Temperature (˚F)")
plt.xlabel("Latitude")
plt.grid()

print(f"The r-squared is: {rvalue**2}")
plt.savefig("output_data/citynorthlatvsmaxtemp.png")
plt.savefig("output_data/Fig5.png")
plt.show()
# Out:
# The r-squared is: 0.7717902712984022

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Max Temp ˚F']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-26,50),fontsize=15,color="red")

plt.scatter(southhem["Lat"],southhem["Max Temp ˚F"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("Southern Latitude vs. Max. Temperature  "+"("+chartdate+")")
plt.ylabel("Max. Temperature (˚F)")
plt.xlabel("Latitude")
plt.grid()

print(f"The r-squared is: {rvalue**2}")
plt.savefig("output_data/citynorthlatvsmaxtemp.png")
plt.savefig("output_data/Fig6.png")
plt.show()
# Out:
# The r-squared is: 0.4129942652982772

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northhem['Lat']
y_values = northhem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,5),fontsize=15,color="red")
plt.title("Northern Latitudes vs. Humidity (%) "+"("+chartdate+")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
print(f"The r-squared is: {rvalue**2}")
plt.savefig("output_data/northlatvshumidity.png")
plt.savefig("output_data/Fig7.png")
plt.show()
# Out:
# The r-squared is: 0.05733952322270648

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,5),fontsize=15,color="red")


plt.title("Southern Latitudes vs. Humidity (%) "+"("+chartdate+")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
print(f"The r-squared is: {rvalue**2}")
plt.savefig("output_data/southlatvshumidity.png")
plt.savefig("output_data/Fig8.png")
plt.show()
# Out:
# The r-squared is: 0.20511450936520126

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northhem['Lat']
y_values = northhem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,45),fontsize=15,color="red")
plt.title("Northern Latitudes vs. Cloudiness (%) "+"("+chartdate+")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
print(f"The r-squared is: {rvalue**2}")
plt.savefig("output_data/northlatvscloudiness.png")
plt.savefig("output_data/Fig9.png")
plt.show()
# Out:
# The r-squared is: 0.018450615273214302

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,45),fontsize=15,color="red")
plt.title("Southern Latitudes vs. Cloudiness (%) "+"("+chartdate+")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
print(f"The r-squared is: {rvalue**2}")
plt.savefig("output_data/southlatvscloudiness.png")
plt.savefig("output_data/Fig10.png")
plt.show()
# Out:
# The r-squared is: 0.05955488692262107

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northhem['Lat']
y_values = northhem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,25),fontsize=15,color="red")
plt.title("Northern Latitudes vs. Windspeed (%) "+"("+chartdate+")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
print(f"The r-squared is: {rvalue**2}")
plt.savefig("output_data/northlatvsWindspeed.png")
plt.savefig("output_data/Fig11.png")
plt.show()
# Out:
# The r-squared is: 0.04416072317716855

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,13),fontsize=15,color="red")
plt.title("Southern Latitudes vs. Windspeed (%) "+"("+chartdate+")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
print(f"The r-squared is: {rvalue**2}")
plt.savefig("output_data/southlatvsWindspeed.png")
plt.savefig("output_data/Fig12.png")
plt.show()
# Out:
# The r-squared is: 0.06347795494998083

# %%
#Create one single image with multiple plots

# %%
from PIL import Image
im1=Image.open("output_data/fig1.png")
im2=Image.open("output_data/fig2.png")
def get_concat_h(im1, im2):
    dst = Image.new('RGB', (im1.width + im2.width, im1.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    return dst
get_concat_h(im1, im2).save('output_data/fig13.jpg')

# %%
im3=Image.open("output_data/fig3.png")
im4=Image.open("output_data/fig4.png")
def get_concat_h(im3, im4):
    dst = Image.new('RGB', (im3.width + im4.width, im3.height))
    dst.paste(im3, (0, 0))
    dst.paste(im4, (im3.width, 0))
    return dst
get_concat_h(im3, im4).save('output_data/fig14.jpg')

# %%
im5=Image.open("output_data/fig5.png")
im6=Image.open("output_data/fig6.png")
def get_concat_h(im5, im6):
    dst = Image.new('RGB', (im5.width + im6.width, im5.height))
    dst.paste(im5, (0, 0))
    dst.paste(im6, (im5.width, 0))
    return dst
get_concat_h(im5, im6).save('output_data/fig15.jpg')

# %%
im7=Image.open("output_data/fig7.png")
im8=Image.open("output_data/fig8.png")
def get_concat_h(im7, im8):
    dst = Image.new('RGB', (im7.width + im8.width, im7.height))
    dst.paste(im7, (0, 0))
    dst.paste(im8, (im7.width, 0))
    return dst
get_concat_h(im5, im6).save('output_data/fig16.jpg')

# %%
im9=Image.open("output_data/fig9.png")
im10=Image.open("output_data/fig10.png")
def get_concat_h(im9, im10):
    dst = Image.new('RGB', (im9.width + im10.width, im9.height))
    dst.paste(im9, (0, 0))
    dst.paste(im10, (im9.width, 0))
    return dst
get_concat_h(im9, im10).save('output_data/fig17.jpg')

# %%
im11=Image.open("output_data/fig11.png")
im12=Image.open("output_data/fig12.png")
def get_concat_h(im11, im12):
    dst = Image.new('RGB', (im11.width + im12.width, im11.height))
    dst.paste(im11, (0, 0))
    dst.paste(im12, (im11.width, 0))
    return dst
get_concat_h(im11, im12).save('output_data/fig18.jpg')

# %%
im13=Image.open("output_data/fig13.jpg")
im14=Image.open("output_data/fig14.jpg")
def get_concat_h(im13, im14):
    dst = Image.new('RGB', (im13.width + im14.width, im13.height))
    dst.paste(im13, (0, 0))
    dst.paste(im14, (im13.width, 0))
    return dst
get_concat_h(im13, im14).save('output_data/fig19.jpg')

# %%
im15=Image.open("output_data/fig15.jpg")
im16=Image.open("output_data/fig16.jpg")
def get_concat_h(im15, im16):
    dst = Image.new('RGB', (im15.width + im16.width, im15.height))
    dst.paste(im15, (0, 0))
    dst.paste(im16, (im15.width, 0))
    return dst
get_concat_h(im15, im16).save('output_data/fig20.jpg')

# %%
im17=Image.open("output_data/fig17.jpg")
im18=Image.open("output_data/fig18.jpg")
def get_concat_h(im17, im18):
    dst = Image.new('RGB', (im17.width + im18.width, im17.height))
    dst.paste(im17, (0, 0))
    dst.paste(im18, (im17.width, 0))
    return dst
get_concat_h(im17, im18).save('output_data/fig21.jpg')

# %%
im19=Image.open("output_data/fig19.jpg")
im20=Image.open("output_data/fig20.jpg")
def get_concat_v(im19, im20):
    dst = Image.new('RGB', (im19.width, im19.height + im20.height))
    dst.paste(im19, (0, 0))
    dst.paste(im20, (0, im19.height))
    return dst

get_concat_v(im19, im20).save('output_data/fig22.jpg')

# %%
im21=Image.open("output_data/fig21.jpg")
im22=Image.open("output_data/fig22.jpg")
def get_concat_v(im22, im21):
    dst = Image.new('RGB', (im22.width, im22.height + im21.height))
    dst.paste(im22, (0, 0))
    dst.paste(im21, (0, im22.height))
    return dst

get_concat_v(im22, im21).save('output_data/fig23.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-258-e478b6bfbf4a> in <module>
#       5     return dst
#       6
# ----> 7 get_concat_v(im22, im21).save('output_data/fig23.jpg')
#
# NameError: name 'im22' is not defined
