# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress
import json
from datetime import datetime

# Import API key
from api_keys import weather_api_key
API_KEY=weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
totcitydata=(len(cities))
if len(cities)>500:
    print("Okay to Proceed")
else:
    print("Need More City Data")
# Out:
# 622
# Okay to Proceed

# %%
cities
# Out:
# ['longyearbyen',
#  'rairangpur',
#  'fortuna',
#  'hithadhoo',
#  'urdzhar',
#  'cape town',
#  'airai',
#  'tasiilaq',
#  'porto velho',
#  'nikolskoye',
#  'khani',
#  'dzaoudzi',
#  'marsh harbour',
#  'attawapiskat',
#  'waingapu',
#  'mataura',
#  'hihifo',
#  'vaini',
#  'albany',
#  'kapaa',
#  'ushuaia',
#  'victoria',
#  'hofn',
#  'rikitea',
#  'hualmay',
#  'atuona',
#  'yulara',
#  'maldonado',
#  'khromtau',
#  'ketchikan',
#  'zhigansk',
#  'skara',
#  'tuktoyaktuk',
#  'bredasdorp',
#  'port alfred',
#  'bambous virieux',
#  'manbij',
#  'sitka',
#  'ambilobe',
#  'howard springs',
#  'amderma',
#  'vanimo',
#  'thompson',
#  'tura',
#  'port blair',
#  'makakilo city',
#  'jamestown',
#  'ancud',
#  'taolanaro',
#  'raudeberg',
#  'nanortalik',
#  'hilo',
#  'kjopsvik',
#  'pirovskoye',
#  'bluff',
#  'mar del plata',
#  'katsuura',
#  'mahebourg',
#  'holeby',
#  'viedma',
#  'norman wells',
#  'cap malheureux',
#  'iqaluit',
#  'belushya guba',
#  'georgetown',
#  'noumea',
#  'atar',
#  'busselton',
#  'monte redondo',
#  'shibetsu',
#  'acapulco',
#  'bubaque',
#  'sur',
#  'ewa beach',
#  'lanja',
#  'chokurdakh',
#  'san juan',
#  'garmsar',
#  'lompoc',
#  'punta arenas',
#  'qandala',
#  'arraial do cabo',
#  'broken hill',
#  'ribeira grande',
#  'port hawkesbury',
#  'hobart',
#  'new norfolk',
#  'batagay-alyta',
#  'qaanaaq',
#  'zhezkazgan',
#  'yellowknife',
#  'bambanglipuro',
#  'baykit',
#  'pemba',
#  'talcahuano',
#  'westport',
#  'provideniya',
#  'pisco',
#  'cape coral',
#  'sentyabrskiy',
#  'nioro',
#  'mys shmidta',
#  'le moule',
#  'the valley',
#  'tuy hoa',
#  'ginir',
#  'dolbeau',
#  'faanui',
#  'novoagansk',
#  'kahului',
#  'atambua',
#  'iranshahr',
#  'paamiut',
#  'sao filipe',
#  'lebu',
#  'saint george',
#  'chuy',
#  'plettenberg bay',
#  'puerto ayora',
#  'itoman',
#  'mananjary',
#  'dikson',
#  'hasaki',
#  'takapau',
#  'illoqqortoormiut',
#  'kodiak',
#  'hermanus',
#  'honghu',
#  'ahuimanu',
#  'salalah',
#  'porbandar',
#  'vaitupu',
#  'luderitz',
#  'mahdasht',
#  'saint-philippe',
#  'aklavik',
#  'fort nelson',
#  'siocon',
#  'khatanga',
#  'vila franca do campo',
#  'laguna',
#  'mount isa',
#  'tuni',
#  'mecca',
#  'barranca',
#  'ponta delgada',
#  'cape canaveral',
#  'maxixe',
#  'barentsburg',
#  'kaitangata',
#  'north bend',
#  'souillac',
#  'upernavik',
#  'cap-aux-meules',
#  'grand-santi',
#  'presidencia roque saenz pena',
#  'leningradskiy',
#  'kamenskoye',
#  'severo-kurilsk',
#  'petropavlovsk-kamchatskiy',
#  'shangzhi',
#  'champerico',
#  'tautira',
#  'namibe',
#  'avarua',
#  'butaritari',
#  'la asuncion',
#  'mikhaylovka',
#  'espanola',
#  'bargal',
#  'havre-saint-pierre',
#  'labuhan',
#  'bandarbeyla',
#  'calama',
#  'korla',
#  'tumannyy',
#  'mercedes',
#  'amapa',
#  'la romana',
#  'mgandu',
#  'surgut',
#  'koshki',
#  'cherskiy',
#  'staryy nadym',
#  'takab',
#  'itapaci',
#  'hanstholm',
#  'eskasem',
#  'saleaula',
#  'kununurra',
#  'mackenzie',
#  'tiksi',
#  'fenoarivo',
#  'tsabong',
#  'cockburn town',
#  'aksay',
#  'mazagao',
#  'catamarca',
#  'karaul',
#  'kumano',
#  'sudbury',
#  'nong ki',
#  'gunjur',
#  'los llanos de aridane',
#  'vardo',
#  'rio claro',
#  'terra santa',
#  'maniitsoq',
#  'vestmanna',
#  'ambon',
#  'caloundra',
#  'avera',
#  'port augusta',
#  'olafsvik',
#  'castro',
#  'mezen',
#  'port elizabeth',
#  'kavieng',
#  'isangel',
#  'narsaq',
#  'vao',
#  'ponta do sol',
#  'swan hill',
#  'rennes',
#  'neuquen',
#  'chebenki',
#  'yabrud',
#  'socorro',
#  'asfi',
#  'pacasmayo',
#  'balsas',
#  'pontes e lacerda',
#  'millinocket',
#  'bathsheba',
#  'hobyo',
#  'zepce',
#  'melong',
#  'altagracia de orituco',
#  'coquimbo',
#  'cayenne',
#  'tambura',
#  'saskylakh',
#  'lorengau',
#  'pemangkat',
#  'sakaiminato',
#  'naftah',
#  'la orilla',
#  'jalu',
#  'redlands',
#  'nipawin',
#  'kutum',
#  'cabo san lucas',
#  'beira',
#  'tanggu',
#  'woodward',
#  'xining',
#  'pangnirtung',
#  'talnakh',
#  'ivanteyevka',
#  'maceio',
#  'saldanha',
#  'coihaique',
#  'lagoa',
#  'umzimvubu',
#  'palmer',
#  'klaksvik',
#  'sovetskiy',
#  'carnarvon',
#  'lazaro cardenas',
#  'south venice',
#  'ilhabela',
#  'sarangani',
#  'privas',
#  'yhu',
#  'mitchell',
#  'anaconda',
#  'micheweni',
#  'bengkulu',
#  'acarau',
#  'bethel',
#  'san patricio',
#  'callaway',
#  'houma',
#  'barrow',
#  'barbar',
#  'lolua',
#  'quatre cocos',
#  'lamu',
#  'grindavik',
#  'togur',
#  'east london',
#  'campoverde',
#  'touros',
#  'ilulissat',
#  'cozumel',
#  'uruzgan',
#  'esperance',
#  'sembe',
#  'port arthur',
#  'ormara',
#  'zeya',
#  'roma',
#  'mangai',
#  'cabra',
#  'paytug',
#  'buraydah',
#  'mpraeso',
#  'tessalit',
#  'manzini',
#  'palabuhanratu',
#  'bekwai',
#  'emerald',
#  'baloda bazar',
#  'sioux lookout',
#  'manzil tamim',
#  'mankono',
#  'neiafu',
#  'beisfjord',
#  'rawson',
#  'sao sebastiao',
#  'hemsedal',
#  'flinders',
#  'nabire',
#  'yamada',
#  'lavrentiya',
#  'la libertad',
#  'geraldton',
#  'khovu-aksy',
#  'gardan diwal',
#  'iquique',
#  'benguela',
#  'saint anthony',
#  'pedasi',
#  'kindersley',
#  'skalistyy',
#  'vila velha',
#  'itarema',
#  'hami',
#  'saint-augustin',
#  'mariani',
#  'mildura',
#  'dingle',
#  'pevek',
#  'sungaipenuh',
#  'cajnice',
#  'merrill',
#  'alta floresta',
#  'graham',
#  'tolaga bay',
#  'bull savanna',
#  'awjilah',
#  'achisay',
#  'urengoy',
#  'goundam',
#  'cidreira',
#  'galiwinku',
#  'ust-kamchatsk',
#  'rantauprapat',
#  'teya',
#  'grand island',
#  'anadyr',
#  'waipawa',
#  'baracoa',
#  'beloha',
#  'tuatapere',
#  'santiago del estero',
#  'maarianhamina',
#  'goderich',
#  'livingstonia',
#  'oda',
#  'springbok',
#  'provost',
#  'warqla',
#  'centralia',
#  'santa eulalia del rio',
#  'margate',
#  'sorvag',
#  'bogalusa',
#  'djambala',
#  'pareora',
#  'salinopolis',
#  'inhambane',
#  'port-gentil',
#  'constitucion',
#  'codrington',
#  'tsihombe',
#  'bara',
#  'sept-iles',
#  'hovd',
#  'vostok',
#  'banjar',
#  'pitkyaranta',
#  'paracuru',
#  'touba',
#  'khyriv',
#  'broome',
#  'kidal',
#  'zorritos',
#  'chifeng',
#  'hirara',
#  'winnemucca',
#  'kodinsk',
#  'berlevag',
#  'lao cai',
#  'gat',
#  'ola',
#  'zhuhai',
#  'berezanka',
#  'general roca',
#  'sribne',
#  'kruisfontein',
#  'horasan',
#  'sechura',
#  'fraserburgh',
#  'karratha',
#  'ngunguru',
#  'kenai',
#  'yialos',
#  'nizwa',
#  'seoul',
#  'ostrovnoy',
#  'port lincoln',
#  'suozhen',
#  'sandwick',
#  'adrar',
#  'evensk',
#  'nishihara',
#  'kerema',
#  'guerrero negro',
#  'lake cowichan',
#  'riyadh',
#  'ruatoria',
#  'tasbuget',
#  'northam',
#  'tyup',
#  'clyde river',
#  'samusu',
#  'grand gaube',
#  'kemijarvi',
#  'longjiang',
#  'inta',
#  'yatou',
#  'orocue',
#  'kulhudhuffushi',
#  'rzhev',
#  'iracoubo',
#  'kasongo',
#  'coari',
#  'la ronge',
#  'mount gambier',
#  'taoudenni',
#  'yefira',
#  'meulaboh',
#  'berea',
#  'bafq',
#  'zaragoza',
#  'manicore',
#  'dwarka',
#  'oksfjord',
#  'santarem',
#  'fonte boa',
#  'bure',
#  'saint paul',
#  'honiara',
#  'eureka',
#  'dickson',
#  'san lorenzo',
#  'pangody',
#  'whitianga',
#  'lishui',
#  'san luis',
#  'san matias',
#  'oktyabrskiy',
#  'pyshchug',
#  'bearsden',
#  'port hedland',
#  'le vauclin',
#  'torbay',
#  'glens falls',
#  'honavar',
#  'mehamn',
#  'ahvaz',
#  'marolambo',
#  'aykino',
#  'pochutla',
#  'moba',
#  'walla walla',
#  'trinidad',
#  'cravo norte',
#  'srednekolymsk',
#  'marzuq',
#  'baruun-urt',
#  'caravelas',
#  'mayumba',
#  'balkhash',
#  'sungurlu',
#  'cananea',
#  'tabuk',
#  'nizhneyansk',
#  'jaguey grande',
#  'sterling',
#  'bukachacha',
#  'farafangana',
#  'chapada dos guimaraes',
#  'hwange',
#  'abha',
#  'lynn haven',
#  'novoaleksandrovsk',
#  'lata',
#  'pandhana',
#  'sao joao da barra',
#  'ramjibanpur',
#  'benghazi',
#  'coahuayana',
#  'mahon',
#  'angoche',
#  'haukipudas',
#  'anju',
#  'lasa',
#  'cuamba',
#  'kabanjahe',
#  'hambantota',
#  'nueve de julio',
#  'zolotinka',
#  'mopipi',
#  'namatanai',
#  'kropotkin',
#  'thunder bay',
#  'kaili',
#  'elizabeth city',
#  'pandan',
#  'nara',
#  'porto empedocle',
#  'port hardy',
#  'ati',
#  'roebourne',
#  'sayula',
#  'kapoeta',
#  'terra rica',
#  'ongandjera',
#  'buchanan',
#  'marawi',
#  'malanville',
#  'bamako',
#  'araouane',
#  'kalmar',
#  'azare',
#  'anloga',
#  'bourail',
#  'darhan',
#  'mykolayivka',
#  'faro',
#  'iskateley',
#  'morro bay',
#  'pa daet',
#  'bolobo',
#  'urgut',
#  'inderborskiy',
#  'katakwi',
#  'donskoye',
#  'padang',
#  'najran',
#  'sosnovo-ozerskoye',
#  'ouallam',
#  'marcona',
#  'lismore',
#  'agadez',
#  'harper',
#  'husavik',
#  'san buenaventura',
#  'beroroha',
#  'muriwai beach',
#  'kaeo',
#  'bolungarvik',
#  'mangrol',
#  'ornes',
#  'alofi',
#  'ugoofaaru',
#  'bilma',
#  'makung',
#  'farnham',
#  'dudinka',
#  'yar-sale',
#  'mullaitivu',
#  'hervey bay',
#  'ust-koksa',
#  'shunyi',
#  'porto novo',
#  'kaniv',
#  'hastings',
#  'zurrieq',
#  'venado tuerto',
#  'dunedin',
#  'owando',
#  'sorland',
#  'sinnamary',
#  'aborlan',
#  'denpasar',
#  'boyle',
#  'dickinson',
#  'at-bashi',
#  'eregli',
#  'te anau',
#  'kholtoson',
#  'belmonte',
#  'maua',
#  'rosetta',
#  'busayra',
#  'beitbridge',
#  'pinawa',
#  'walvis bay',
#  'khor',
#  'shreveport',
#  'utiroa',
#  'saquena',
#  'fairbanks',
#  'wahiawa',
#  'oga',
#  'usinsk',
#  'sargatskoye',
#  'vila do maio',
#  'rio grande']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_KEY
response = requests.get(f"{url}&q={city}").json() 
response
# Out:
# {'coord': {'lon': -156.7887, 'lat': 71.2906},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 10.4,
#   'feels_like': 0.79,
#   'temp_min': 10.4,
#   'temp_max': 10.4,
#   'pressure': 1029,
#   'humidity': 79},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 100},
#  'clouds': {'all': 40},
#  'dt': 1618517288,
#  'sys': {'type': 1,
#   'id': 7649,
#   'country': 'US',
#   'sunrise': 1618495732,
#   'sunset': 1618555488},
#  'timezone': -28800,
#  'id': 5880054,
#  'name': 'Barrow',
#  'cod': 200}

# %%
city
# Out:
# 'barrow'

# %%
#Json weather check for each city and print log
city_name = []
clouds = []
country = []
wind_speed = []
date = []
latitude = []
longitude = []
max_temp = []
humidity = []

counter=1
print(f"Weather Data Processing Initialization")
print(f"______________________________________")
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_KEY
for city in cities:
    try:
        response=requests.get(f"{url}&q={city}").json()
        city_name.append(response["name"])
        clouds.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {counter} of {totcitydata} | {city_record}")
        counter=counter+1

# If no record found "skip" to next call
    except:
        print("City not found. Skipping this location...")
    continue
# Out:
# Weather Data Processing Initialization
# ______________________________________
# Processing Record 1 of 622 | Longyearbyen
# Processing Record 2 of 622 | Rairangpur
# Processing Record 3 of 622 | Fortuna
# Processing Record 4 of 622 | Hithadhoo
# City not found. Skipping this location...
# Processing Record 5 of 622 | Cape Town
# Processing Record 6 of 622 | Airai
# Processing Record 7 of 622 | Tasiilaq
# Processing Record 8 of 622 | Porto Velho
# Processing Record 9 of 622 | Nikolskoye
# Processing Record 10 of 622 | Khani
# Processing Record 11 of 622 | Dzaoudzi
# Processing Record 12 of 622 | Marsh Harbour
# City not found. Skipping this location...
# Processing Record 13 of 622 | Waingapu
# Processing Record 14 of 622 | Mataura
# City not found. Skipping this location...
# Processing Record 15 of 622 | Vaini
# Processing Record 16 of 622 | Albany
# Processing Record 17 of 622 | Kapaa
# Processing Record 18 of 622 | Ushuaia
# Processing Record 19 of 622 | Hong Kong
# Processing Record 20 of 622 | Hofn
# Processing Record 21 of 622 | Rikitea
# Processing Record 22 of 622 | Hualmay
# Processing Record 23 of 622 | Atuona
# Processing Record 24 of 622 | Yulara
# Processing Record 25 of 622 | Departamento de Maldonado
# Processing Record 26 of 622 | Khromtau
# Processing Record 27 of 622 | Ketchikan
# Processing Record 28 of 622 | Zhigansk
# Processing Record 29 of 622 | Skara
# Processing Record 30 of 622 | Tuktoyaktuk
# Processing Record 31 of 622 | Bredasdorp
# Processing Record 32 of 622 | Port Alfred
# Processing Record 33 of 622 | Bambous Virieux
# Processing Record 34 of 622 | Manbij
# Processing Record 35 of 622 | Sitka
# Processing Record 36 of 622 | Ambilobe
# Processing Record 37 of 622 | Howard Springs
# City not found. Skipping this location...
# Processing Record 38 of 622 | Vanimo
# Processing Record 39 of 622 | Thompson
# Processing Record 40 of 622 | Tura
# Processing Record 41 of 622 | Port Blair
# Processing Record 42 of 622 | Makakilo City
# Processing Record 43 of 622 | Jamestown
# Processing Record 44 of 622 | Ancud
# City not found. Skipping this location...
# Processing Record 45 of 622 | Raudeberg
# Processing Record 46 of 622 | Nanortalik
# Processing Record 47 of 622 | Hilo
# Processing Record 48 of 622 | Kjøpsvik
# Processing Record 49 of 622 | Pirovskoye
# Processing Record 50 of 622 | Bluff
# Processing Record 51 of 622 | Mar del Plata
# Processing Record 52 of 622 | Katsuura
# Processing Record 53 of 622 | Mahébourg
# Processing Record 54 of 622 | Holeby
# Processing Record 55 of 622 | Viedma
# Processing Record 56 of 622 | Norman Wells
# Processing Record 57 of 622 | Cap Malheureux
# Processing Record 58 of 622 | Iqaluit
# City not found. Skipping this location...
# Processing Record 59 of 622 | George Town
# Processing Record 60 of 622 | Noumea
# Processing Record 61 of 622 | Atar
# Processing Record 62 of 622 | Busselton
# Processing Record 63 of 622 | Monte Redondo
# Processing Record 64 of 622 | Shibetsu
# Processing Record 65 of 622 | Acapulco de Juárez
# Processing Record 66 of 622 | Bubaque
# Processing Record 67 of 622 | Sur
# Processing Record 68 of 622 | ‘Ewa Beach
# Processing Record 69 of 622 | Lānja
# Processing Record 70 of 622 | Chokurdakh
# Processing Record 71 of 622 | San Juan
# Processing Record 72 of 622 | Garmsār
# Processing Record 73 of 622 | Lompoc
# Processing Record 74 of 622 | Punta Arenas
# Processing Record 75 of 622 | Qandala
# Processing Record 76 of 622 | Arraial do Cabo
# Processing Record 77 of 622 | Broken Hill
# Processing Record 78 of 622 | Ribeira Grande
# Processing Record 79 of 622 | Port Hawkesbury
# Processing Record 80 of 622 | Hobart
# Processing Record 81 of 622 | New Norfolk
# Processing Record 82 of 622 | Batagay-Alyta
# Processing Record 83 of 622 | Qaanaaq
# Processing Record 84 of 622 | Zhezkazgan
# Processing Record 85 of 622 | Yellowknife
# Processing Record 86 of 622 | Bambanglipuro
# Processing Record 87 of 622 | Baykit
# Processing Record 88 of 622 | Pemba
# Processing Record 89 of 622 | Talcahuano
# Processing Record 90 of 622 | Westport
# Processing Record 91 of 622 | Provideniya
# Processing Record 92 of 622 | Pisco
# Processing Record 93 of 622 | Cape Coral
# City not found. Skipping this location...
# Processing Record 94 of 622 | Nioro
# City not found. Skipping this location...
# Processing Record 95 of 622 | Le Moule
# Processing Record 96 of 622 | The Valley
# Processing Record 97 of 622 | Tuy Hoa
# Processing Record 98 of 622 | Ginir
# City not found. Skipping this location...
# Processing Record 99 of 622 | Faanui
# Processing Record 100 of 622 | Novoagansk
# Processing Record 101 of 622 | Kahului
# Processing Record 102 of 622 | Atambua
# Processing Record 103 of 622 | Iranshahr
# Processing Record 104 of 622 | Paamiut
# Processing Record 105 of 622 | São Filipe
# Processing Record 106 of 622 | Lebu
# Processing Record 107 of 622 | Saint George
# Processing Record 108 of 622 | Chui
# Processing Record 109 of 622 | Plettenberg Bay
# Processing Record 110 of 622 | Puerto Ayora
# Processing Record 111 of 622 | Itoman
# Processing Record 112 of 622 | Mananjary
# Processing Record 113 of 622 | Dikson
# Processing Record 114 of 622 | Hasaki
# Processing Record 115 of 622 | Takapau
# City not found. Skipping this location...
# Processing Record 116 of 622 | Saint Paul Harbor
# Processing Record 117 of 622 | Hermanus
# Processing Record 118 of 622 | Honghu
# Processing Record 119 of 622 | ‘Āhuimanu
# Processing Record 120 of 622 | Salalah
# Processing Record 121 of 622 | Porbandar
# City not found. Skipping this location...
# Processing Record 122 of 622 | Lüderitz
# Processing Record 123 of 622 | Mahdasht
# Processing Record 124 of 622 | Saint-Philippe
# Processing Record 125 of 622 | Aklavik
# Processing Record 126 of 622 | Fort Nelson
# Processing Record 127 of 622 | Siocon
# Processing Record 128 of 622 | Khatanga
# Processing Record 129 of 622 | Vila Franca do Campo
# Processing Record 130 of 622 | Laguna
# Processing Record 131 of 622 | Mount Isa
# Processing Record 132 of 622 | Tuni
# Processing Record 133 of 622 | Makkah al Mukarramah
# Processing Record 134 of 622 | Barranca
# Processing Record 135 of 622 | Ponta Delgada
# Processing Record 136 of 622 | Cape Canaveral
# Processing Record 137 of 622 | Maxixe
# City not found. Skipping this location...
# Processing Record 138 of 622 | Kaitangata
# Processing Record 139 of 622 | North Bend
# Processing Record 140 of 622 | Souillac
# Processing Record 141 of 622 | Upernavik
# Processing Record 142 of 622 | Cap-aux-Meules
# Processing Record 143 of 622 | Grand-Santi
# Processing Record 144 of 622 | Presidencia Roque Sáenz Peña
# Processing Record 145 of 622 | Leningradskiy
# City not found. Skipping this location...
# Processing Record 146 of 622 | Severo-Kuril'sk
# Processing Record 147 of 622 | Petropavlovsk-Kamchatskiy
# Processing Record 148 of 622 | Shangzhi
# Processing Record 149 of 622 | Champerico
# Processing Record 150 of 622 | Tautira
# Processing Record 151 of 622 | Mossamedes
# Processing Record 152 of 622 | Avarua
# Processing Record 153 of 622 | Butaritari
# Processing Record 154 of 622 | La Asuncion
# Processing Record 155 of 622 | Mikhaylovka
# Processing Record 156 of 622 | Española
# City not found. Skipping this location...
# Processing Record 157 of 622 | Havre-St-Pierre
# Processing Record 158 of 622 | Labuhan
# Processing Record 159 of 622 | Bandarbeyla
# Processing Record 160 of 622 | Calama
# Processing Record 161 of 622 | Korla
# City not found. Skipping this location...
# Processing Record 162 of 622 | Mercedes
# Processing Record 163 of 622 | Amapá
# Processing Record 164 of 622 | La Romana
# Processing Record 165 of 622 | Mgandu
# Processing Record 166 of 622 | Surgut
# Processing Record 167 of 622 | Koshki
# Processing Record 168 of 622 | Cherskiy
# Processing Record 169 of 622 | Staryy Nadym
# Processing Record 170 of 622 | Takāb
# Processing Record 171 of 622 | Itapaci
# Processing Record 172 of 622 | Hanstholm
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 173 of 622 | Kununurra
# Processing Record 174 of 622 | Mackenzie
# Processing Record 175 of 622 | Tiksi
# Processing Record 176 of 622 | Fenoarivo
# Processing Record 177 of 622 | Tsabong
# Processing Record 178 of 622 | Cockburn Town
# Processing Record 179 of 622 | Aksay
# Processing Record 180 of 622 | Mazagão
# Processing Record 181 of 622 | San Fernando del Valle de Catamarca
# City not found. Skipping this location...
# Processing Record 182 of 622 | Kumano
# Processing Record 183 of 622 | Greater Sudbury
# Processing Record 184 of 622 | Nong Ki
# Processing Record 185 of 622 | Gunjur
# Processing Record 186 of 622 | Los Llanos de Aridane
# Processing Record 187 of 622 | Vardø
# Processing Record 188 of 622 | Rio Claro
# Processing Record 189 of 622 | Terra Santa
# Processing Record 190 of 622 | Maniitsoq
# Processing Record 191 of 622 | Vestmanna
# Processing Record 192 of 622 | Ambon City
# Processing Record 193 of 622 | Caloundra
# Processing Record 194 of 622 | Avera
# Processing Record 195 of 622 | Port Augusta
# Processing Record 196 of 622 | Olafsvik
# Processing Record 197 of 622 | Castro
# Processing Record 198 of 622 | Mezen'
# Processing Record 199 of 622 | Port Elizabeth
# Processing Record 200 of 622 | Kavieng
# Processing Record 201 of 622 | Isangel
# Processing Record 202 of 622 | Narsaq
# Processing Record 203 of 622 | Vao
# Processing Record 204 of 622 | Ponta do Sol
# Processing Record 205 of 622 | Swan Hill
# Processing Record 206 of 622 | Arrondissement de Rennes
# Processing Record 207 of 622 | Neuquén
# Processing Record 208 of 622 | Chebenki
# Processing Record 209 of 622 | Yabrūd
# Processing Record 210 of 622 | Socorro
# Processing Record 211 of 622 | Safi
# Processing Record 212 of 622 | Pacasmayo
# Processing Record 213 of 622 | Balsas
# Processing Record 214 of 622 | Pontes e Lacerda
# Processing Record 215 of 622 | Millinocket
# Processing Record 216 of 622 | Bathsheba
# Processing Record 217 of 622 | Hobyo
# Processing Record 218 of 622 | Žepče
# Processing Record 219 of 622 | Melong
# Processing Record 220 of 622 | Altagracia de Orituco
# Processing Record 221 of 622 | Coquimbo
# Processing Record 222 of 622 | Cayenne
# Processing Record 223 of 622 | Tambura
# Processing Record 224 of 622 | Saskylakh
# Processing Record 225 of 622 | Lorengau
# Processing Record 226 of 622 | Pemangkat
# Processing Record 227 of 622 | Sakaiminato
# City not found. Skipping this location...
# Processing Record 228 of 622 | La Orilla
# Processing Record 229 of 622 | Jalu
# Processing Record 230 of 622 | Redlands
# Processing Record 231 of 622 | Nipawin
# Processing Record 232 of 622 | Kutum
# Processing Record 233 of 622 | Cabo San Lucas
# Processing Record 234 of 622 | Beira
# Processing Record 235 of 622 | Taku
# Processing Record 236 of 622 | Woodward
# Processing Record 237 of 622 | Xining
# Processing Record 238 of 622 | Pangnirtung
# Processing Record 239 of 622 | Talnakh
# Processing Record 240 of 622 | Ivanteyevka
# Processing Record 241 of 622 | Maceió
# Processing Record 242 of 622 | Saldanha
# Processing Record 243 of 622 | Coyhaique
# Processing Record 244 of 622 | Lagoa
# City not found. Skipping this location...
# Processing Record 245 of 622 | Palmer
# Processing Record 246 of 622 | Klaksvík
# Processing Record 247 of 622 | Sovetskiy
# Processing Record 248 of 622 | Carnarvon
# Processing Record 249 of 622 | Lázaro Cárdenas
# Processing Record 250 of 622 | South Venice
# Processing Record 251 of 622 | Ilhabela
# Processing Record 252 of 622 | Sarangani
# Processing Record 253 of 622 | Arrondissement de Privas
# Processing Record 254 of 622 | Yhú
# Processing Record 255 of 622 | Mitchell
# Processing Record 256 of 622 | Anaconda
# Processing Record 257 of 622 | Micheweni
# Processing Record 258 of 622 | Bengkulu
# Processing Record 259 of 622 | Acaraú
# Processing Record 260 of 622 | Bethel
# Processing Record 261 of 622 | San Patricio
# Processing Record 262 of 622 | Callaway
# Processing Record 263 of 622 | Houma
# Processing Record 264 of 622 | Barrow
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 265 of 622 | Quatre Cocos
# Processing Record 266 of 622 | Lamu
# Processing Record 267 of 622 | Grindavik
# Processing Record 268 of 622 | Togur
# Processing Record 269 of 622 | East London
# Processing Record 270 of 622 | Campoverde
# Processing Record 271 of 622 | Touros
# Processing Record 272 of 622 | Ilulissat
# Processing Record 273 of 622 | San Miguel de Cozumel
# Processing Record 274 of 622 | Oruzgan
# Processing Record 275 of 622 | Esperance
# Processing Record 276 of 622 | Sémbé
# Processing Record 277 of 622 | Lüshunkou
# Processing Record 278 of 622 | Ormara
# Processing Record 279 of 622 | Zeya
# Processing Record 280 of 622 | Rome
# Processing Record 281 of 622 | Mangai
# Processing Record 282 of 622 | Cabra
# City not found. Skipping this location...
# Processing Record 283 of 622 | Buraidah
# Processing Record 284 of 622 | Mpraeso
# Processing Record 285 of 622 | Tessalit
# Processing Record 286 of 622 | Manzini
# City not found. Skipping this location...
# Processing Record 287 of 622 | Bekwai
# Processing Record 288 of 622 | Emerald
# Processing Record 289 of 622 | Baloda Bāzār
# Processing Record 290 of 622 | Sioux Lookout
# City not found. Skipping this location...
# Processing Record 291 of 622 | Mankono
# Processing Record 292 of 622 | Neiafu
# Processing Record 293 of 622 | Beisfjord
# Processing Record 294 of 622 | Rawson
# Processing Record 295 of 622 | São Sebastião
# Processing Record 296 of 622 | Hemsedal
# Processing Record 297 of 622 | Flinders
# Processing Record 298 of 622 | Nabire
# Processing Record 299 of 622 | Yamada
# Processing Record 300 of 622 | Lavrentiya
# Processing Record 301 of 622 | La Libertad
# Processing Record 302 of 622 | Geraldton
# Processing Record 303 of 622 | Khovu-Aksy
# City not found. Skipping this location...
# Processing Record 304 of 622 | Iquique
# Processing Record 305 of 622 | Benguela
# Processing Record 306 of 622 | Saint Anthony
# Processing Record 307 of 622 | Pedasí
# Processing Record 308 of 622 | Kindersley
# City not found. Skipping this location...
# Processing Record 309 of 622 | Vila Velha
# Processing Record 310 of 622 | Itarema
# Processing Record 311 of 622 | Kumul
# Processing Record 312 of 622 | Saint-Augustin
# Processing Record 313 of 622 | Mariāni
# Processing Record 314 of 622 | Mildura
# Processing Record 315 of 622 | Dingle
# Processing Record 316 of 622 | Pevek
# Processing Record 317 of 622 | Sungai Penuh
# Processing Record 318 of 622 | Čajniče
# Processing Record 319 of 622 | Merrill
# Processing Record 320 of 622 | Alta Floresta
# Processing Record 321 of 622 | Graham
# Processing Record 322 of 622 | Tolaga Bay
# Processing Record 323 of 622 | Bull Savanna
# Processing Record 324 of 622 | Awjilah
# City not found. Skipping this location...
# Processing Record 325 of 622 | Urengoy
# Processing Record 326 of 622 | Goundam
# Processing Record 327 of 622 | Cidreira
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 328 of 622 | Rantauprapat
# Processing Record 329 of 622 | Teya
# Processing Record 330 of 622 | Grand Island
# Processing Record 331 of 622 | Anadyr
# Processing Record 332 of 622 | Waipawa
# Processing Record 333 of 622 | Baracoa
# Processing Record 334 of 622 | Beloha
# Processing Record 335 of 622 | Tuatapere
# Processing Record 336 of 622 | Santiago del Estero
# Processing Record 337 of 622 | Mariehamn
# Processing Record 338 of 622 | Goderich
# Processing Record 339 of 622 | Livingstonia
# Processing Record 340 of 622 | Ōdachō-ōda
# Processing Record 341 of 622 | Springbok
# Processing Record 342 of 622 | Provost
# City not found. Skipping this location...
# Processing Record 343 of 622 | Centralia
# City not found. Skipping this location...
# Processing Record 344 of 622 | Margate
# City not found. Skipping this location...
# Processing Record 345 of 622 | Bogalusa
# Processing Record 346 of 622 | Djambala
# Processing Record 347 of 622 | Pareora
# Processing Record 348 of 622 | Salinópolis
# Processing Record 349 of 622 | Inhambane
# Processing Record 350 of 622 | Port-Gentil
# Processing Record 351 of 622 | Constitución
# Processing Record 352 of 622 | Codrington
# City not found. Skipping this location...
# Processing Record 353 of 622 | Bara
# Processing Record 354 of 622 | Sept-Îles
# Processing Record 355 of 622 | Khovd
# Processing Record 356 of 622 | Vostok
# Processing Record 357 of 622 | Banjar
# Processing Record 358 of 622 | Pitkyaranta
# Processing Record 359 of 622 | Paracuru
# Processing Record 360 of 622 | Touba
# Processing Record 361 of 622 | Khyriv
# Processing Record 362 of 622 | Broome
# Processing Record 363 of 622 | Kidal
# Processing Record 364 of 622 | Zorritos
# Processing Record 365 of 622 | Chifeng
# Processing Record 366 of 622 | Hirara
# Processing Record 367 of 622 | Winnemucca
# Processing Record 368 of 622 | Kodinsk
# Processing Record 369 of 622 | Berlevåg
# Processing Record 370 of 622 | Lao Cai
# Processing Record 371 of 622 | Kiryat Gat
# Processing Record 372 of 622 | Ola
# Processing Record 373 of 622 | Zhuhai
# Processing Record 374 of 622 | Berezanka
# Processing Record 375 of 622 | General Roca
# Processing Record 376 of 622 | Sribne
# Processing Record 377 of 622 | Kruisfontein
# Processing Record 378 of 622 | Horasan
# Processing Record 379 of 622 | Sechura
# Processing Record 380 of 622 | Fraserburgh
# Processing Record 381 of 622 | Karratha
# Processing Record 382 of 622 | Ngunguru
# Processing Record 383 of 622 | Kenai
# City not found. Skipping this location...
# Processing Record 384 of 622 | Nizwá
# Processing Record 385 of 622 | Seoul
# Processing Record 386 of 622 | Ostrovnoy
# Processing Record 387 of 622 | Port Lincoln
# Processing Record 388 of 622 | Suozhen
# Processing Record 389 of 622 | Sandwick
# Processing Record 390 of 622 | Adrar
# Processing Record 391 of 622 | Evensk
# Processing Record 392 of 622 | Nishihara
# Processing Record 393 of 622 | Kerema
# Processing Record 394 of 622 | Guerrero Negro
# Processing Record 395 of 622 | Lake Cowichan
# Processing Record 396 of 622 | Riyadh
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 397 of 622 | Northam
# Processing Record 398 of 622 | Tyup
# Processing Record 399 of 622 | Clyde River
# City not found. Skipping this location...
# Processing Record 400 of 622 | Grand Gaube
# Processing Record 401 of 622 | Kemijärvi
# Processing Record 402 of 622 | Longjiang
# Processing Record 403 of 622 | Inta
# Processing Record 404 of 622 | Yatou
# Processing Record 405 of 622 | Orocué
# Processing Record 406 of 622 | Kulhudhuffushi
# Processing Record 407 of 622 | Rzhev
# Processing Record 408 of 622 | Iracoubo
# Processing Record 409 of 622 | Kasongo
# Processing Record 410 of 622 | Coari
# Processing Record 411 of 622 | La Ronge
# Processing Record 412 of 622 | Mount Gambier
# Processing Record 413 of 622 | Taoudenni
# City not found. Skipping this location...
# Processing Record 414 of 622 | Meulaboh
# Processing Record 415 of 622 | Berea
# Processing Record 416 of 622 | Bāfq
# Processing Record 417 of 622 | Zaragoza
# Processing Record 418 of 622 | Manicoré
# Processing Record 419 of 622 | Dwārka
# Processing Record 420 of 622 | Øksfjord
# Processing Record 421 of 622 | Santarém
# Processing Record 422 of 622 | Fonte Boa
# Processing Record 423 of 622 | Burē
# Processing Record 424 of 622 | Saint Paul
# Processing Record 425 of 622 | Honiara
# Processing Record 426 of 622 | Eureka
# Processing Record 427 of 622 | Dickson
# Processing Record 428 of 622 | San Lorenzo
# Processing Record 429 of 622 | Pangody
# Processing Record 430 of 622 | Whitianga
# Processing Record 431 of 622 | Lishui
# Processing Record 432 of 622 | San Luis
# Processing Record 433 of 622 | San Matías
# Processing Record 434 of 622 | Oktyabr'skiy
# Processing Record 435 of 622 | Pyshchug
# Processing Record 436 of 622 | Bearsden
# Processing Record 437 of 622 | Port Hedland
# Processing Record 438 of 622 | Le Vauclin
# Processing Record 439 of 622 | Torbay
# Processing Record 440 of 622 | Glens Falls
# Processing Record 441 of 622 | Honāvar
# Processing Record 442 of 622 | Mehamn
# Processing Record 443 of 622 | Ahvāz
# Processing Record 444 of 622 | Marolambo
# Processing Record 445 of 622 | Aykino
# Processing Record 446 of 622 | Pochutla
# Processing Record 447 of 622 | Moba
# Processing Record 448 of 622 | Walla Walla
# Processing Record 449 of 622 | La Santisima Trinidad
# Processing Record 450 of 622 | Cravo Norte
# Processing Record 451 of 622 | Srednekolymsk
# Processing Record 452 of 622 | Marzuq
# Processing Record 453 of 622 | Baruun-Urt
# Processing Record 454 of 622 | Caravelas
# Processing Record 455 of 622 | Mayumba
# Processing Record 456 of 622 | Balkhash
# Processing Record 457 of 622 | Sungurlu
# Processing Record 458 of 622 | Cananea
# Processing Record 459 of 622 | Tabuk
# City not found. Skipping this location...
# Processing Record 460 of 622 | Jagüey Grande
# Processing Record 461 of 622 | Sterling
# Processing Record 462 of 622 | Bukachacha
# Processing Record 463 of 622 | Farafangana
# Processing Record 464 of 622 | Chapada dos Guimarães
# Processing Record 465 of 622 | Hwange
# Processing Record 466 of 622 | Abhā
# Processing Record 467 of 622 | Lynn Haven
# Processing Record 468 of 622 | Novoaleksandrovsk
# Processing Record 469 of 622 | Lata
# Processing Record 470 of 622 | Pandhāna
# Processing Record 471 of 622 | São João da Barra
# Processing Record 472 of 622 | Rāmjībanpur
# Processing Record 473 of 622 | Benghazi
# Processing Record 474 of 622 | Coahuayana Viejo
# Processing Record 475 of 622 | Mahon
# Processing Record 476 of 622 | Angoche
# Processing Record 477 of 622 | Haukipudas
# Processing Record 478 of 622 | Anju
# Processing Record 479 of 622 | Laas
# Processing Record 480 of 622 | Cuamba
# Processing Record 481 of 622 | Kabanjahe
# Processing Record 482 of 622 | Hambantota
# Processing Record 483 of 622 | Nueve de Julio
# City not found. Skipping this location...
# Processing Record 484 of 622 | Mopipi
# Processing Record 485 of 622 | Namatanai
# Processing Record 486 of 622 | Kropotkin
# Processing Record 487 of 622 | Thunder Bay
# Processing Record 488 of 622 | Kaili
# Processing Record 489 of 622 | Elizabeth City
# Processing Record 490 of 622 | Pandan
# Processing Record 491 of 622 | Nara
# Processing Record 492 of 622 | Porto Empedocle
# Processing Record 493 of 622 | Port Hardy
# Processing Record 494 of 622 | Ati
# Processing Record 495 of 622 | Roebourne
# Processing Record 496 of 622 | Sayula
# Processing Record 497 of 622 | Kapoeta
# Processing Record 498 of 622 | Terra Rica
# Processing Record 499 of 622 | Ongandjera
# Processing Record 500 of 622 | Buchanan
# Processing Record 501 of 622 | Marawi
# Processing Record 502 of 622 | Malanville
# Processing Record 503 of 622 | Bamako
# Processing Record 504 of 622 | Araouane
# Processing Record 505 of 622 | Kalmar
# Processing Record 506 of 622 | Azare
# Processing Record 507 of 622 | Anloga
# Processing Record 508 of 622 | Bourail
# Processing Record 509 of 622 | Darhan
# Processing Record 510 of 622 | Mykolayivka
# Processing Record 511 of 622 | Faro
# Processing Record 512 of 622 | Iskateley
# Processing Record 513 of 622 | Morro Bay
# Processing Record 514 of 622 | Pa Daet
# Processing Record 515 of 622 | Bolobo
# Processing Record 516 of 622 | Urgut
# City not found. Skipping this location...
# Processing Record 517 of 622 | Katakwi
# Processing Record 518 of 622 | Donskoye
# Processing Record 519 of 622 | Padang
# Processing Record 520 of 622 | Najrān
# Processing Record 521 of 622 | Sosnovo-Ozerskoye
# Processing Record 522 of 622 | Ouallam
# City not found. Skipping this location...
# Processing Record 523 of 622 | Lismore
# Processing Record 524 of 622 | Agadez
# Processing Record 525 of 622 | Harper
# Processing Record 526 of 622 | Husavik
# Processing Record 527 of 622 | San Buenaventura
# Processing Record 528 of 622 | Beroroha
# Processing Record 529 of 622 | Muriwai Beach
# Processing Record 530 of 622 | Kaeo
# City not found. Skipping this location...
# Processing Record 531 of 622 | Māngrol
# Processing Record 532 of 622 | Ørnes
# Processing Record 533 of 622 | Alofi
# Processing Record 534 of 622 | Ugoofaaru
# Processing Record 535 of 622 | Bilma
# City not found. Skipping this location...
# Processing Record 536 of 622 | Farnham
# Processing Record 537 of 622 | Dudinka
# Processing Record 538 of 622 | Yar-Sale
# City not found. Skipping this location...
# Processing Record 539 of 622 | Hervey Bay
# Processing Record 540 of 622 | Ust'-Koksa
# Processing Record 541 of 622 | Shunyi
# Processing Record 542 of 622 | Porto-Novo
# Processing Record 543 of 622 | Kaniv
# Processing Record 544 of 622 | Hastings
# Processing Record 545 of 622 | Żurrieq
# Processing Record 546 of 622 | Venado Tuerto
# Processing Record 547 of 622 | Dunedin
# Processing Record 548 of 622 | Owando
# Processing Record 549 of 622 | Sørland
# Processing Record 550 of 622 | Sinnamary
# Processing Record 551 of 622 | Aborlan
# Processing Record 552 of 622 | Denpasar
# Processing Record 553 of 622 | Boyle
# Processing Record 554 of 622 | Dickinson
# Processing Record 555 of 622 | At-Bashi
# Processing Record 556 of 622 | Heraclea
# Processing Record 557 of 622 | Te Anau
# Processing Record 558 of 622 | Kholtoson
# Processing Record 559 of 622 | Belmonte
# Processing Record 560 of 622 | Mauá
# Processing Record 561 of 622 | Rosetta
# Processing Record 562 of 622 | Buşayrā
# Processing Record 563 of 622 | Beitbridge
# Processing Record 564 of 622 | Pinawa
# Processing Record 565 of 622 | Walvis Bay
# Processing Record 566 of 622 | Khor
# Processing Record 567 of 622 | Shreveport
# City not found. Skipping this location...
# Processing Record 568 of 622 | Saquena
# Processing Record 569 of 622 | Fairbanks
# Processing Record 570 of 622 | Wahiawā
# Processing Record 571 of 622 | Oga
# Processing Record 572 of 622 | Usinsk
# Processing Record 573 of 622 | Sargatskoye
# Processing Record 574 of 622 | Vila do Maio
# Processing Record 575 of 622 | Rio Grande

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data=pd.DataFrame({"City":city_name,
                        "Cloudiness":clouds,
                        "Country":country,
                        "Date":date,
                        "Humidity":humidity,
                        "Lat":latitude,
                        "Lng":longitude,
                        "Max Temp":max_temp,
                        "Wind Speed":wind_speed})
city_data
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 0    Longyearbyen          75      SJ  1618517296        68  78.2186
# 1      Rairangpur         100      IN  1618517296        30  22.2676
# 2         Fortuna           1      US  1618517297        72  40.5982
# 3       Hithadhoo          57      MV  1618517126        69  -0.6000
# 4       Cape Town           0      ZA  1618516893        72 -33.9258
# ..            ...         ...     ...         ...       ...      ...
# 570           Oga          75      IT  1618517455        68  46.4631
# 571        Usinsk          51      RU  1618517232        68  65.9939
# 572   Sargatskoye          79      RU  1618517455        92  55.6101
# 573  Vila do Maio          75      CV  1618517456        73  15.1333
# 574    Rio Grande          75      BR  1618517456        88 -32.0350
#
#           Lng  Max Temp  Wind Speed
# 0     15.6401     23.00       10.36
# 1     86.1751     82.38        5.55
# 2   -124.1573     62.01       12.66
# 3     73.0833     82.36        4.70
# 4     18.4232     66.20       18.41
# ..        ...       ...         ...
# 570   10.3470     42.01        4.61
# 571   57.5281     18.97        4.83
# 572   73.4972     44.13       10.63
# 573  -23.2167     71.60       21.85
# 574  -52.0986     69.80        6.91
#
# [575 rows x 9 columns]

# %%
city_data["Humidity"].max()
# Out:
# 100

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data.count()
# Out:
# City          575
# Cloudiness    575
# Country       575
# Date          575
# Humidity      575
# Lat           575
# Lng           575
# Max Temp      575
# Wind Speed    575
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
#convert unix timestamp to date time - pandas.pydata.org time series/date functionality
city_data["Date"]=pd.to_datetime(city_data["Date"],unit="s")
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=city_data[["City","Lat","Lng","Max Temp","Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]]
clean_sort=clean_city_data.sort_values(by='City',ascending=True).reset_index(drop=True)
clean_sort
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  Abhā  18.2164   42.5053     66.20        59          40
# 1               Aborlan   9.4352  118.5492     77.56        81          92
# 2    Acapulco de Juárez  16.8634  -99.8901     86.00        66          40
# 3                Acaraú  -2.8856  -40.1200     81.52        79          92
# 4                 Adrar  20.5022  -10.0711     83.05        18          23
# ..                  ...      ...       ...       ...       ...         ...
# 570          Ōdachō-ōda  35.1833  132.5000     48.20        66          14
# 571             Żurrieq  35.8311   14.4742     59.00        77          20
# 572               Žepče  44.4267   18.0378     41.00        60          20
# 573          ‘Ewa Beach  21.3156 -158.0072     80.60        50           1
# 574           ‘Āhuimanu  21.4447 -157.8378     80.60        60          40
#
#      Wind Speed Country                Date
# 0         11.50      SA 2021-04-15 20:10:20
# 1          3.31      PH 2021-04-15 20:10:49
# 2         10.36      MX 2021-04-15 20:07:09
# 3         12.19      BR 2021-04-15 20:09:07
# 4         10.63      MR 2021-04-15 20:09:55
# ..          ...     ...                 ...
# 570       10.00      JP 2021-04-15 20:09:42
# 571       19.57      MT 2021-04-15 20:10:46
# 572        1.14      BA 2021-04-15 20:09:10
# 573        6.91      US 2021-04-15 20:06:59
# 574        5.75      US 2021-04-15 20:08:43
#
# [575 rows x 9 columns]

# %%
clean_sort=clean_sort.rename(columns={"Max Temp":"Max Temp ˚F"})
clean_sort
clean_sort.to_csv('output_data/cities.csv',index=True,header=True)
datadate=((clean_sort.iloc[0,8]))
chartdate=(datadate.strftime("%b %d, %Y"))

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Max Temp ˚F"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Max. Temperature  "+"("+chartdate+")")
plt.ylabel("Max. Temperature (˚F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvsmaxtemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Humidity"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Humidity  "+"("+chartdate+")")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvshumidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Cloudiness"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Cloudiness (%)  "+"("+chartdate+")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvscloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Wind Speed"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Wind Speed  "+"("+chartdate+")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvsmaxtemp.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northhem=clean_sort[clean_sort['Lat']>=0]
southhem=clean_sort[clean_sort['Lat']<0]

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
