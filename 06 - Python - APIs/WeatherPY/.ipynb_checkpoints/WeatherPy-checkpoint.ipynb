# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress
import json
from datetime import datetime
import PIL as PIL

# Import API key
from api_keys import weather_api_key
API_KEY=weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
totcitydata=(len(cities))
if len(cities)>500:
    print("Okay to Proceed")
else:
    print("Need More City Data")
# Out:
# 638
# Okay to Proceed

# %%
cities
# Out:
# ['puerto ayora',
#  'atar',
#  'coquimbo',
#  'carnarvon',
#  'luderitz',
#  'isangel',
#  'coruripe',
#  'kitui',
#  'albany',
#  'samusu',
#  'zabaykalsk',
#  'inta',
#  'mataura',
#  'usinsk',
#  'cullman',
#  'illoqqortoormiut',
#  'turukhansk',
#  'tateyama',
#  'laguna',
#  'zhigansk',
#  'kapaa',
#  'madang',
#  'urdzhar',
#  'ushuaia',
#  'tuatapere',
#  'road town',
#  'meulaboh',
#  'obera',
#  'kailua',
#  'shelburne',
#  'vila velha',
#  'mantua',
#  'rikitea',
#  'bredasdorp',
#  'nha trang',
#  'dingle',
#  'safford',
#  'butaritari',
#  'saskylakh',
#  'dikson',
#  'esperance',
#  'haines junction',
#  'bokspits',
#  'ancud',
#  'westport',
#  'cabo san lucas',
#  'iqaluit',
#  'ligatne',
#  'cape town',
#  'new norfolk',
#  'barrow',
#  'tuktoyaktuk',
#  'bathsheba',
#  'pisco',
#  'ojitlan',
#  'tasiilaq',
#  'puerto madero',
#  'east london',
#  'khatanga',
#  'pokhara',
#  'busselton',
#  'vershino-shakhtaminskiy',
#  'punta arenas',
#  'kamenka',
#  'bainbridge',
#  'huilong',
#  'sydney',
#  'kapoeta',
#  'sulzbach-rosenberg',
#  'eyl',
#  'saldanha',
#  'velizh',
#  'kropotkin',
#  'asfi',
#  'upernavik',
#  'krasnoselkup',
#  'barentsburg',
#  'longyearbyen',
#  'lavrentiya',
#  'palu',
#  'adrar',
#  'esna',
#  'provideniya',
#  'fairbanks',
#  'rio gallegos',
#  'karamken',
#  'lorengau',
#  'vardo',
#  'nanortalik',
#  'horizontina',
#  'mahebourg',
#  'ostrovnoy',
#  'manta',
#  'hobart',
#  'la ronge',
#  'codrington',
#  'baykit',
#  'tumannyy',
#  'viligili',
#  'georgetown',
#  'neuquen',
#  'payson',
#  'yankton',
#  'san cristobal',
#  'atuona',
#  'manono',
#  'mamallapuram',
#  'worland',
#  'santa marinella',
#  'itarema',
#  'albanel',
#  'gijon',
#  'amderma',
#  'mayumba',
#  'quelimane',
#  'chuy',
#  'aleksandrovsk-sakhalinskiy',
#  'marcona',
#  'hilo',
#  'attawapiskat',
#  'port alfred',
#  'annau',
#  'jamestown',
#  'malakal',
#  'kaitangata',
#  'sonda',
#  'iquique',
#  'mar del plata',
#  'bluff',
#  'ulaangom',
#  'kodiak',
#  'quatre cocos',
#  'torbay',
#  'salalah',
#  'sholokhove',
#  'yellowknife',
#  'qaanaaq',
#  'khonuu',
#  'pemangkat',
#  'moba',
#  'bin qirdan',
#  'taseyevo',
#  'ilulissat',
#  'maniitsoq',
#  'kurumkan',
#  'amga',
#  'lebu',
#  'belushya guba',
#  'longlac',
#  'borogontsy',
#  'yumen',
#  'suntar',
#  'mys shmidta',
#  'belyy yar',
#  'karratha',
#  'saint george',
#  'yuzhno-yeniseyskiy',
#  'nikolskoye',
#  'cordoba',
#  'victor harbor',
#  'olafsvik',
#  'krasnoarmeysk',
#  'hasaki',
#  'paamiut',
#  'ponta do sol',
#  'katsuura',
#  'tautira',
#  'peniche',
#  'north bend',
#  'celestun',
#  'yertsevo',
#  'borba',
#  'houma',
#  'hithadhoo',
#  'rohri',
#  'mets masrik',
#  'vaini',
#  'acajutla',
#  'great falls',
#  'yanji',
#  'nevsehir',
#  'channel-port aux basques',
#  'talcahuano',
#  'coahuayana',
#  'karasburg',
#  'hermanus',
#  'tsihombe',
#  'ornskoldsvik',
#  'tucuman',
#  'zeya',
#  'yulara',
#  'mount gambier',
#  'henties bay',
#  'taolanaro',
#  'kristianstad',
#  'clyde river',
#  'curug',
#  'sao jose da coroa grande',
#  'balrampur',
#  'mao',
#  'linchuan',
#  'kirakira',
#  'chokurdakh',
#  'prince rupert',
#  'palabuhanratu',
#  'meyungs',
#  'gandajika',
#  'boden',
#  'xixiang',
#  'svetlyy',
#  'bolungarvik',
#  'tazovskiy',
#  'flinders',
#  'sorland',
#  'jinchang',
#  'santa cruz',
#  'toliary',
#  'itoman',
#  'denekamp',
#  'pangnirtung',
#  'hami',
#  'whitehorse',
#  'grand river south east',
#  'namibe',
#  'bengkulu',
#  'cherskiy',
#  'kiunga',
#  'stornoway',
#  'kastamonu',
#  'grindavik',
#  'airai',
#  'castro',
#  'acapulco',
#  'katakwi',
#  'nome',
#  'komsomolskiy',
#  'nizhneyansk',
#  'bandarbeyla',
#  'akdepe',
#  'point pedro',
#  'mehendiganj',
#  'aden',
#  'bambanglipuro',
#  'sao filipe',
#  'thunder bay',
#  'karpogory',
#  'clevelandia',
#  'san jeronimo',
#  'kuloy',
#  'nacala',
#  'warqla',
#  'kieta',
#  'sumbawanga',
#  'vestmannaeyjar',
#  'severo-kurilsk',
#  'timra',
#  'husavik',
#  'cap-aux-meules',
#  'narsaq',
#  'avarua',
#  'cap malheureux',
#  'leningradskiy',
#  'tutoia',
#  'padang',
#  'orgita',
#  'kruisfontein',
#  'port elizabeth',
#  'general roca',
#  'belaya gora',
#  'revelstoke',
#  'olavarria',
#  'kyren',
#  'ust-omchug',
#  'bambous virieux',
#  'alamosa',
#  'vaitupu',
#  'havelock',
#  'caravelas',
#  'port lincoln',
#  'poso',
#  'turayf',
#  'guinayangan',
#  'vazhiny',
#  'ampanihy',
#  'kavieng',
#  'sitka',
#  'brigantine',
#  'kununurra',
#  'isverna',
#  'sakakah',
#  'tiksi',
#  'oktyabrskiy',
#  'pringsewu',
#  'bethel',
#  'gurgan',
#  'choma',
#  'labuhan',
#  'victoria',
#  'thinadhoo',
#  'kloulklubed',
#  'slave lake',
#  'roma',
#  'walvis bay',
#  'nagato',
#  'williston',
#  'santo antonio do sudoeste',
#  'jieshi',
#  'salinopolis',
#  'beruni',
#  'lucapa',
#  'jiddah',
#  'fortuna',
#  'prisacani',
#  'bolshiye uki',
#  'broken hill',
#  'paita',
#  'takapau',
#  'senno',
#  'thompson',
#  'rayagada',
#  'port-cartier',
#  'oneonta',
#  'cockburn town',
#  'dodge city',
#  'carmen',
#  'arraial do cabo',
#  'klaksvik',
#  'oyama',
#  'mehamn',
#  'araouane',
#  'hobyo',
#  'limbang',
#  'mahon',
#  'goderich',
#  'asosa',
#  'gurupi',
#  'guerrero negro',
#  'jeremie',
#  'dunedin',
#  'progreso',
#  'luanda',
#  'hualmay',
#  'jabiru',
#  'tambopata',
#  'rio grande',
#  'port blair',
#  'lagoa',
#  'pevek',
#  'anloga',
#  'maragogi',
#  'kitzbuhel',
#  'binzhou',
#  'burnie',
#  'havre-saint-pierre',
#  'faanui',
#  'chabahar',
#  'salaya',
#  'batemans bay',
#  'banjar',
#  'ribeira grande',
#  'pavlodar',
#  'casper',
#  'san policarpo',
#  'kang',
#  'gamba',
#  'vila franca do campo',
#  'shingu',
#  'kitaibaraki',
#  'hof',
#  'kulebaki',
#  'sumbe',
#  'rungata',
#  'kaman',
#  'jiazi',
#  'khuzhir',
#  'muros',
#  'san quintin',
#  'hambantota',
#  'chicama',
#  'lamidan',
#  'kamenskoye',
#  'lubon',
#  'nuuk',
#  'lucera',
#  'estelle',
#  'san carlos',
#  'labuan',
#  'havoysund',
#  'lednice',
#  'forbes',
#  'qasigiannguit',
#  'sao geraldo do araguaia',
#  'asau',
#  'ayagoz',
#  'newport',
#  'vangaindrano',
#  'port hardy',
#  'dom pedro',
#  'babanusah',
#  'saint anthony',
#  'hrinova',
#  'kegayli',
#  'tilichiki',
#  'quang ngai',
#  'svetlaya',
#  'andra',
#  'leczyca',
#  'zermatt',
#  'filadelfia',
#  'boa vista',
#  'cervo',
#  'honiara',
#  'luxor',
#  'macaboboni',
#  'egvekinot',
#  'stoyba',
#  'kijang',
#  'malanville',
#  'yar-sale',
#  'haverhill',
#  'morbach',
#  'bonfim',
#  'ahipara',
#  'bilibino',
#  'chirongui',
#  'nichinan',
#  'soyo',
#  'valparaiso',
#  'lengshuijiang',
#  'aklavik',
#  'krasnaya gora',
#  'kautokeino',
#  'krasnoyarsk-66',
#  'najran',
#  'mayo',
#  'sao joao da barra',
#  'kumluca',
#  'campos do jordao',
#  'kaeo',
#  'sterling',
#  'kulhudhuffushi',
#  'shahrud',
#  'longhua',
#  'moree',
#  'raudeberg',
#  'mandalgovi',
#  'zalari',
#  'lucea',
#  'kahului',
#  'tarudant',
#  'angren',
#  'birao',
#  'dosso',
#  'ust-kamchatsk',
#  'dhanera',
#  'orhangazi',
#  'akalgarh',
#  'sao raimundo das mangabeiras',
#  'chagda',
#  'artyk',
#  'black river',
#  'irtyshskiy',
#  'curup',
#  'mercedes',
#  'tomatlan',
#  'ishigaki',
#  'dunmore',
#  'brahmapuri',
#  'santa maria',
#  'viedma',
#  'dhidhdhoo',
#  'grand gaube',
#  'santa fe',
#  'coihaique',
#  'manokwari',
#  'burica',
#  'zile',
#  'taywarah',
#  'kupang',
#  'changping',
#  'opuwo',
#  'madimba',
#  'thilogne',
#  'longkou',
#  'camopi',
#  'souillac',
#  'saint-pierre',
#  'naze',
#  'bangkalan',
#  'oranjemund',
#  'baragua',
#  'sarakhs',
#  'cairns',
#  'kretinga',
#  'ternate',
#  'sabha',
#  'darnah',
#  'ibra',
#  'saint-philippe',
#  'eenhana',
#  'noumea',
#  'cedar city',
#  'indramayu',
#  'gallup',
#  'homer',
#  'fuente palmera',
#  'gaogou',
#  'broome',
#  'astoria',
#  'abnub',
#  'puerto escondido',
#  'oussouye',
#  'porto novo',
#  'necochea',
#  'koulikoro',
#  'bukama',
#  'bend',
#  'ballina',
#  'san miguel',
#  'tura',
#  'avera',
#  'lompoc',
#  'strezhevoy',
#  'kargopol',
#  'portland',
#  'mvuma',
#  'fukue',
#  'neiafu',
#  'sioux lookout',
#  'trairi',
#  'geraldton',
#  'saint-francois',
#  'panguna',
#  'la macarena',
#  'waingapu',
#  'goba',
#  'pathein',
#  'tawkar',
#  'ambulu',
#  'arvika',
#  'gaoual',
#  'pecos',
#  'norman wells',
#  'praia da vitoria',
#  'berlevag',
#  'tsienyane',
#  'rawson',
#  'le port',
#  'sri aman',
#  'caraballeda',
#  'bergen',
#  'naftalan',
#  'anadyr',
#  'luneburg',
#  'terrace bay',
#  'okandja',
#  'mount isa',
#  'saint-joseph',
#  'camargo',
#  'sucua',
#  'abha',
#  'tumaco',
#  'halalo',
#  'deputatskiy',
#  'cidreira',
#  'margate',
#  'diamantino',
#  'dunyapur',
#  'telemaco borba',
#  'pitimbu',
#  'leua',
#  'vila praia de ancora',
#  'kholtoson',
#  'wahran',
#  'shubarshi',
#  'aasiaat',
#  'valea argovei',
#  'kabalo',
#  'contamana',
#  'college',
#  'tessalit',
#  'mbaiki',
#  'phangnga',
#  'ankpa',
#  'camacha',
#  'haibowan',
#  'canguaretama',
#  'gawler',
#  'nabire',
#  'abbeville',
#  'teya',
#  'buin',
#  'samalaeulu',
#  'tevaitoa',
#  'esso',
#  'qaqortoq',
#  'mogadishu',
#  'omboue',
#  'kavaratti',
#  'chardara',
#  'los llanos de aridane',
#  'ugoofaaru',
#  'phan rang',
#  'san vicente',
#  'san patricio',
#  'melita',
#  'can tho',
#  'yamada',
#  'etchoropo',
#  'sorvag',
#  'carauari',
#  'port hedland',
#  'muroto',
#  'pucara',
#  'port-gentil',
#  'tukrah',
#  'batsfjord',
#  'aracoiaba da serra',
#  'saquena',
#  'nkongsamba',
#  'kazanskoye',
#  'coari',
#  'imeni babushkina',
#  'nouadhibou',
#  'buala',
#  'ereymentau',
#  'umzimvubu',
#  'mareeba',
#  'kungurtug',
#  'tongren',
#  'innisfail',
#  'oranjestad',
#  'touros',
#  'aykhal',
#  'kuppam',
#  'san felipe',
#  'mitu',
#  'pokrovsk']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_KEY
response = requests.get(f"{url}&q={city}").json() 
response
# Out:
# {'coord': {'lon': 37.1758, 'lat': 48.282},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 37.26,
#   'feels_like': 32.58,
#   'temp_min': 37.26,
#   'temp_max': 37.26,
#   'pressure': 1020,
#   'humidity': 91,
#   'sea_level': 1020,
#   'grnd_level': 995},
#  'visibility': 10000,
#  'wind': {'speed': 5.88, 'deg': 251, 'gust': 8.08},
#  'clouds': {'all': 12},
#  'dt': 1618627469,
#  'sys': {'country': 'UA', 'sunrise': 1618627043, 'sunset': 1618676634},
#  'timezone': 10800,
#  'id': 704422,
#  'name': "Krasnoarmiys'k",
#  'cod': 200}

# %%
city
# Out:
# 'pokrovsk'

# %%
#Json weather check for each city and print log
city_name = []
clouds = []
country = []
wind_speed = []
date = []
latitude = []
longitude = []
max_temp = []
humidity = []

counter=1
print(f"Weather Data Processing Initialization")
print(f"______________________________________")
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_KEY
for city in cities:
    try:
        response=requests.get(f"{url}&q={city}").json()
        city_name.append(response["name"])
        clouds.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {counter} of {totcitydata} | {city_record}")
        counter=counter+1

# If no record found "skip" to next call
    except:
        print("City not found. Skipping this location...")
    continue
# Out:
# Weather Data Processing Initialization
# ______________________________________
# Processing Record 1 of 638 | Puerto Ayora
# Processing Record 2 of 638 | Atar
# Processing Record 3 of 638 | Coquimbo
# Processing Record 4 of 638 | Carnarvon
# Processing Record 5 of 638 | Lüderitz
# Processing Record 6 of 638 | Isangel
# Processing Record 7 of 638 | Coruripe
# Processing Record 8 of 638 | Kitui
# Processing Record 9 of 638 | Albany
# City not found. Skipping this location...
# Processing Record 10 of 638 | Zabaykal'sk
# Processing Record 11 of 638 | Inta
# Processing Record 12 of 638 | Mataura
# Processing Record 13 of 638 | Usinsk
# Processing Record 14 of 638 | Cullman
# City not found. Skipping this location...
# Processing Record 15 of 638 | Turukhansk
# Processing Record 16 of 638 | Tateyama
# Processing Record 17 of 638 | Laguna
# Processing Record 18 of 638 | Zhigansk
# Processing Record 19 of 638 | Kapaa
# Processing Record 20 of 638 | Madang
# City not found. Skipping this location...
# Processing Record 21 of 638 | Ushuaia
# Processing Record 22 of 638 | Tuatapere
# Processing Record 23 of 638 | Road Town
# Processing Record 24 of 638 | Meulaboh
# Processing Record 25 of 638 | Oberá
# Processing Record 26 of 638 | Kailua
# Processing Record 27 of 638 | Shelburne
# Processing Record 28 of 638 | Vila Velha
# Processing Record 29 of 638 | Province of Mantua
# Processing Record 30 of 638 | Rikitea
# Processing Record 31 of 638 | Bredasdorp
# Processing Record 32 of 638 | Nha Trang
# Processing Record 33 of 638 | Dingle
# Processing Record 34 of 638 | Safford
# Processing Record 35 of 638 | Butaritari
# Processing Record 36 of 638 | Saskylakh
# Processing Record 37 of 638 | Dikson
# Processing Record 38 of 638 | Esperance
# Processing Record 39 of 638 | Haines Junction
# City not found. Skipping this location...
# Processing Record 40 of 638 | Ancud
# Processing Record 41 of 638 | Westport
# Processing Record 42 of 638 | Cabo San Lucas
# Processing Record 43 of 638 | Iqaluit
# Processing Record 44 of 638 | Līgatne
# Processing Record 45 of 638 | Cape Town
# Processing Record 46 of 638 | New Norfolk
# Processing Record 47 of 638 | Barrow
# Processing Record 48 of 638 | Tuktoyaktuk
# Processing Record 49 of 638 | Bathsheba
# Processing Record 50 of 638 | Pisco
# City not found. Skipping this location...
# Processing Record 51 of 638 | Tasiilaq
# Processing Record 52 of 638 | Puerto Madero
# Processing Record 53 of 638 | East London
# Processing Record 54 of 638 | Khatanga
# Processing Record 55 of 638 | Pokhara
# Processing Record 56 of 638 | Busselton
# Processing Record 57 of 638 | Vershino-Shakhtaminskiy
# Processing Record 58 of 638 | Punta Arenas
# Processing Record 59 of 638 | Kamenka
# Processing Record 60 of 638 | Bainbridge Island
# Processing Record 61 of 638 | Huilong
# Processing Record 62 of 638 | Sydney
# Processing Record 63 of 638 | Kapoeta
# Processing Record 64 of 638 | Sulzbach-Rosenberg
# Processing Record 65 of 638 | Eyl
# Processing Record 66 of 638 | Saldanha
# Processing Record 67 of 638 | Velizh
# Processing Record 68 of 638 | Kropotkin
# Processing Record 69 of 638 | Safi
# Processing Record 70 of 638 | Upernavik
# Processing Record 71 of 638 | Krasnosel'kup
# City not found. Skipping this location...
# Processing Record 72 of 638 | Longyearbyen
# Processing Record 73 of 638 | Lavrentiya
# Processing Record 74 of 638 | Palu
# Processing Record 75 of 638 | Adrar
# Processing Record 76 of 638 | Esna
# Processing Record 77 of 638 | Provideniya
# Processing Record 78 of 638 | Fairbanks
# Processing Record 79 of 638 | Río Gallegos
# City not found. Skipping this location...
# Processing Record 80 of 638 | Lorengau
# Processing Record 81 of 638 | Vardø
# Processing Record 82 of 638 | Nanortalik
# Processing Record 83 of 638 | Horizontina
# Processing Record 84 of 638 | Mahébourg
# Processing Record 85 of 638 | Ostrovnoy
# Processing Record 86 of 638 | Manta
# Processing Record 87 of 638 | Hobart
# Processing Record 88 of 638 | La Ronge
# Processing Record 89 of 638 | Codrington
# Processing Record 90 of 638 | Baykit
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 91 of 638 | George Town
# Processing Record 92 of 638 | Neuquén
# Processing Record 93 of 638 | Payson
# Processing Record 94 of 638 | Yankton
# Processing Record 95 of 638 | San Cristobal
# Processing Record 96 of 638 | Atuona
# Processing Record 97 of 638 | Manono
# Processing Record 98 of 638 | Mahabalipuram
# Processing Record 99 of 638 | Worland
# Processing Record 100 of 638 | Santa Marinella
# Processing Record 101 of 638 | Itarema
# Processing Record 102 of 638 | Albanel
# Processing Record 103 of 638 | Gijón
# City not found. Skipping this location...
# Processing Record 104 of 638 | Mayumba
# Processing Record 105 of 638 | Quelimane
# Processing Record 106 of 638 | Chui
# Processing Record 107 of 638 | Aleksandrovsk-Sakhalinskiy
# City not found. Skipping this location...
# Processing Record 108 of 638 | Hilo
# City not found. Skipping this location...
# Processing Record 109 of 638 | Port Alfred
# Processing Record 110 of 638 | Annau
# Processing Record 111 of 638 | Jamestown
# Processing Record 112 of 638 | Malakal
# Processing Record 113 of 638 | Kaitangata
# Processing Record 114 of 638 | Sonda
# Processing Record 115 of 638 | Iquique
# Processing Record 116 of 638 | Mar del Plata
# Processing Record 117 of 638 | Bluff
# Processing Record 118 of 638 | Ulaangom
# Processing Record 119 of 638 | Saint Paul Harbor
# Processing Record 120 of 638 | Quatre Cocos
# Processing Record 121 of 638 | Torbay
# Processing Record 122 of 638 | Salalah
# Processing Record 123 of 638 | Sholokhove
# Processing Record 124 of 638 | Yellowknife
# Processing Record 125 of 638 | Qaanaaq
# City not found. Skipping this location...
# Processing Record 126 of 638 | Pemangkat
# Processing Record 127 of 638 | Moba
# Processing Record 128 of 638 | Ben Gardane
# Processing Record 129 of 638 | Taseyevo
# Processing Record 130 of 638 | Ilulissat
# Processing Record 131 of 638 | Maniitsoq
# Processing Record 132 of 638 | Kurumkan
# Processing Record 133 of 638 | Amga
# Processing Record 134 of 638 | Lebu
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 135 of 638 | Borogontsy
# Processing Record 136 of 638 | Yumen
# Processing Record 137 of 638 | Suntar
# City not found. Skipping this location...
# Processing Record 138 of 638 | Belyy Yar
# Processing Record 139 of 638 | Karratha
# Processing Record 140 of 638 | Saint George
# City not found. Skipping this location...
# Processing Record 141 of 638 | Nikolskoye
# Processing Record 142 of 638 | Córdoba
# Processing Record 143 of 638 | Victor Harbor
# Processing Record 144 of 638 | Olafsvik
# Processing Record 145 of 638 | Krasnoarmeysk
# Processing Record 146 of 638 | Hasaki
# Processing Record 147 of 638 | Paamiut
# Processing Record 148 of 638 | Ponta do Sol
# Processing Record 149 of 638 | Katsuura
# Processing Record 150 of 638 | Tautira
# Processing Record 151 of 638 | Peniche
# Processing Record 152 of 638 | North Bend
# Processing Record 153 of 638 | Celestún
# Processing Record 154 of 638 | Yertsevo
# Processing Record 155 of 638 | Borba
# Processing Record 156 of 638 | Houma
# Processing Record 157 of 638 | Hithadhoo
# Processing Record 158 of 638 | Rohri
# Processing Record 159 of 638 | Mets Masrik
# Processing Record 160 of 638 | Vaini
# Processing Record 161 of 638 | Acajutla
# Processing Record 162 of 638 | Great Falls
# Processing Record 163 of 638 | Yanji
# Processing Record 164 of 638 | Nevşehir
# Processing Record 165 of 638 | Channel-Port aux Basques
# Processing Record 166 of 638 | Talcahuano
# Processing Record 167 of 638 | Coahuayana Viejo
# Processing Record 168 of 638 | Karasburg
# Processing Record 169 of 638 | Hermanus
# City not found. Skipping this location...
# Processing Record 170 of 638 | Örnsköldsvik
# Processing Record 171 of 638 | San Miguel de Tucumán
# Processing Record 172 of 638 | Zeya
# Processing Record 173 of 638 | Yulara
# Processing Record 174 of 638 | Mount Gambier
# Processing Record 175 of 638 | Henties Bay
# City not found. Skipping this location...
# Processing Record 176 of 638 | Kristianstad
# Processing Record 177 of 638 | Clyde River
# Processing Record 178 of 638 | Curug
# Processing Record 179 of 638 | São José da Coroa Grande
# Processing Record 180 of 638 | Balrāmpur
# Processing Record 181 of 638 | Mahon
# City not found. Skipping this location...
# Processing Record 182 of 638 | Kirakira
# Processing Record 183 of 638 | Chokurdakh
# Processing Record 184 of 638 | Prince Rupert
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 185 of 638 | Gandajika
# Processing Record 186 of 638 | Boden
# Processing Record 187 of 638 | Xixiang
# Processing Record 188 of 638 | Tsimmerbude
# City not found. Skipping this location...
# Processing Record 189 of 638 | Tazovsky
# Processing Record 190 of 638 | Flinders
# Processing Record 191 of 638 | Sørland
# Processing Record 192 of 638 | Jinchang
# Processing Record 193 of 638 | Santa Cruz de la Sierra
# City not found. Skipping this location...
# Processing Record 194 of 638 | Itoman
# Processing Record 195 of 638 | Denekamp
# Processing Record 196 of 638 | Pangnirtung
# Processing Record 197 of 638 | Kumul
# Processing Record 198 of 638 | Whitehorse
# City not found. Skipping this location...
# Processing Record 199 of 638 | Mossamedes
# Processing Record 200 of 638 | Bengkulu
# Processing Record 201 of 638 | Cherskiy
# Processing Record 202 of 638 | Kiunga
# Processing Record 203 of 638 | Stornoway
# Processing Record 204 of 638 | Kastamonu Province
# Processing Record 205 of 638 | Grindavik
# Processing Record 206 of 638 | Airai
# Processing Record 207 of 638 | Castro
# Processing Record 208 of 638 | Acapulco de Juárez
# Processing Record 209 of 638 | Katakwi
# Processing Record 210 of 638 | Nome
# Processing Record 211 of 638 | Yangi Marg`ilon
# City not found. Skipping this location...
# Processing Record 212 of 638 | Bandarbeyla
# Processing Record 213 of 638 | Akdepe
# Processing Record 214 of 638 | Point Pedro
# Processing Record 215 of 638 | Mehendiganj
# Processing Record 216 of 638 | Aden
# Processing Record 217 of 638 | Bambanglipuro
# Processing Record 218 of 638 | São Filipe
# Processing Record 219 of 638 | Thunder Bay
# Processing Record 220 of 638 | Karpogory
# Processing Record 221 of 638 | Clevelândia
# Processing Record 222 of 638 | San Jerónimo
# Processing Record 223 of 638 | Kuloy
# Processing Record 224 of 638 | Nacala
# City not found. Skipping this location...
# Processing Record 225 of 638 | Kieta
# Processing Record 226 of 638 | Sumbawanga
# Processing Record 227 of 638 | Vestmannaeyjar
# Processing Record 228 of 638 | Severo-Kuril'sk
# Processing Record 229 of 638 | Timrå
# Processing Record 230 of 638 | Husavik
# Processing Record 231 of 638 | Cap-aux-Meules
# Processing Record 232 of 638 | Narsaq
# Processing Record 233 of 638 | Avarua
# Processing Record 234 of 638 | Cap Malheureux
# Processing Record 235 of 638 | Leningradskiy
# Processing Record 236 of 638 | Tutóia
# Processing Record 237 of 638 | Padang
# Processing Record 238 of 638 | Orgita
# Processing Record 239 of 638 | Kruisfontein
# Processing Record 240 of 638 | Port Elizabeth
# Processing Record 241 of 638 | General Roca
# Processing Record 242 of 638 | Belaya Gora
# Processing Record 243 of 638 | Revelstoke
# Processing Record 244 of 638 | Olavarría
# Processing Record 245 of 638 | Kyren
# Processing Record 246 of 638 | Ust'-Omchug
# Processing Record 247 of 638 | Bambous Virieux
# Processing Record 248 of 638 | Alamosa
# City not found. Skipping this location...
# Processing Record 249 of 638 | Havelock
# Processing Record 250 of 638 | Caravelas
# Processing Record 251 of 638 | Port Lincoln
# Processing Record 252 of 638 | Poso
# Processing Record 253 of 638 | Turaif
# Processing Record 254 of 638 | Guinayangan, Fourth District of Quezon
# Processing Record 255 of 638 | Vazhiny
# Processing Record 256 of 638 | Ampanihy
# Processing Record 257 of 638 | Kavieng
# Processing Record 258 of 638 | Sitka
# Processing Record 259 of 638 | Brigantine
# Processing Record 260 of 638 | Kununurra
# Processing Record 261 of 638 | Isverna
# Processing Record 262 of 638 | Sakakah
# Processing Record 263 of 638 | Tiksi
# Processing Record 264 of 638 | Oktyabr'skiy
# Processing Record 265 of 638 | Pringsewu
# Processing Record 266 of 638 | Bethel
# City not found. Skipping this location...
# Processing Record 267 of 638 | Choma
# Processing Record 268 of 638 | Labuhan
# Processing Record 269 of 638 | Hong Kong
# Processing Record 270 of 638 | Thinadhoo
# Processing Record 271 of 638 | Kloulklubed
# Processing Record 272 of 638 | Slave Lake
# Processing Record 273 of 638 | Rome
# Processing Record 274 of 638 | Walvis Bay
# Processing Record 275 of 638 | Nagato
# Processing Record 276 of 638 | Williston
# Processing Record 277 of 638 | Santo Antônio do Sudoeste
# Processing Record 278 of 638 | Jieshi
# Processing Record 279 of 638 | Salinópolis
# City not found. Skipping this location...
# Processing Record 280 of 638 | Lucapa
# City not found. Skipping this location...
# Processing Record 281 of 638 | Fortuna
# Processing Record 282 of 638 | Prisăcani
# City not found. Skipping this location...
# Processing Record 283 of 638 | Broken Hill
# Processing Record 284 of 638 | Paita
# Processing Record 285 of 638 | Takapau
# Processing Record 286 of 638 | Senno
# Processing Record 287 of 638 | Thompson
# Processing Record 288 of 638 | Rāyagada
# Processing Record 289 of 638 | Port-Cartier
# Processing Record 290 of 638 | Oneonta
# Processing Record 291 of 638 | Cockburn Town
# Processing Record 292 of 638 | Dodge City
# Processing Record 293 of 638 | Ciudad del Carmen
# Processing Record 294 of 638 | Arraial do Cabo
# Processing Record 295 of 638 | Klaksvík
# Processing Record 296 of 638 | Oyama
# Processing Record 297 of 638 | Mehamn
# Processing Record 298 of 638 | Araouane
# Processing Record 299 of 638 | Hobyo
# Processing Record 300 of 638 | Limbang
# Processing Record 301 of 638 | Mahon
# Processing Record 302 of 638 | Goderich
# Processing Record 303 of 638 | Āsosa
# Processing Record 304 of 638 | Gurupi
# Processing Record 305 of 638 | Guerrero Negro
# Processing Record 306 of 638 | Jérémie
# Processing Record 307 of 638 | Dunedin
# Processing Record 308 of 638 | Progreso
# Processing Record 309 of 638 | Luanda
# Processing Record 310 of 638 | Hualmay
# City not found. Skipping this location...
# Processing Record 311 of 638 | Tambopata
# Processing Record 312 of 638 | Rio Grande
# Processing Record 313 of 638 | Port Blair
# Processing Record 314 of 638 | Lagoa
# Processing Record 315 of 638 | Pevek
# Processing Record 316 of 638 | Anloga
# Processing Record 317 of 638 | Maragogi
# Processing Record 318 of 638 | Kitzbühel
# Processing Record 319 of 638 | Binzhou
# Processing Record 320 of 638 | Burnie
# Processing Record 321 of 638 | Havre-St-Pierre
# Processing Record 322 of 638 | Faanui
# Processing Record 323 of 638 | Chabahar
# Processing Record 324 of 638 | Salāya
# Processing Record 325 of 638 | Batemans Bay
# Processing Record 326 of 638 | Banjar
# Processing Record 327 of 638 | Ribeira Grande
# Processing Record 328 of 638 | Pavlodar
# Processing Record 329 of 638 | Casper
# Processing Record 330 of 638 | San Policarpo
# Processing Record 331 of 638 | Kang
# Processing Record 332 of 638 | Gamba
# Processing Record 333 of 638 | Vila Franca do Campo
# Processing Record 334 of 638 | Shingū
# Processing Record 335 of 638 | Kitaibaraki
# Processing Record 336 of 638 | Hof
# Processing Record 337 of 638 | Kulebaki
# Processing Record 338 of 638 | Sumbe
# City not found. Skipping this location...
# Processing Record 339 of 638 | Kāman
# Processing Record 340 of 638 | Jiazi
# Processing Record 341 of 638 | Khuzhir
# Processing Record 342 of 638 | Muros
# Processing Record 343 of 638 | San Quintín
# Processing Record 344 of 638 | Hambantota
# Processing Record 345 of 638 | Chicama
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 346 of 638 | Luboń
# Processing Record 347 of 638 | Nuuk
# Processing Record 348 of 638 | Lucera
# Processing Record 349 of 638 | Estelle
# Processing Record 350 of 638 | San Carlos
# Processing Record 351 of 638 | Labuan
# Processing Record 352 of 638 | Havøysund
# Processing Record 353 of 638 | Lednice
# Processing Record 354 of 638 | Forbes
# Processing Record 355 of 638 | Qasigiannguit
# Processing Record 356 of 638 | São Geraldo do Araguaia
# Processing Record 357 of 638 | Asău
# Processing Record 358 of 638 | Ayagoz
# Processing Record 359 of 638 | Newport
# Processing Record 360 of 638 | Vangaindrano
# Processing Record 361 of 638 | Port Hardy
# Processing Record 362 of 638 | Dom Pedro
# City not found. Skipping this location...
# Processing Record 363 of 638 | Saint Anthony
# Processing Record 364 of 638 | Hriňová
# City not found. Skipping this location...
# Processing Record 365 of 638 | Tilichiki
# Processing Record 366 of 638 | Quang Ngai
# Processing Record 367 of 638 | Svetlaya
# Processing Record 368 of 638 | Andra
# Processing Record 369 of 638 | Łęczyca
# Processing Record 370 of 638 | Zermatt
# Processing Record 371 of 638 | Philadelphia
# Processing Record 372 of 638 | Boa Vista
# Processing Record 373 of 638 | Cervo
# Processing Record 374 of 638 | Honiara
# Processing Record 375 of 638 | Luxor
# City not found. Skipping this location...
# Processing Record 376 of 638 | Egvekinot
# City not found. Skipping this location...
# Processing Record 377 of 638 | Gijang
# Processing Record 378 of 638 | Malanville
# Processing Record 379 of 638 | Yar-Sale
# Processing Record 380 of 638 | Haverhill
# Processing Record 381 of 638 | Morbach
# Processing Record 382 of 638 | Bonfim
# Processing Record 383 of 638 | Ahipara
# Processing Record 384 of 638 | Bilibino
# Processing Record 385 of 638 | Chirongui
# Processing Record 386 of 638 | Nichinan
# Processing Record 387 of 638 | Soyo
# Processing Record 388 of 638 | Valparaíso
# Processing Record 389 of 638 | Lengshuijiang
# Processing Record 390 of 638 | Aklavik
# Processing Record 391 of 638 | Krasnaya Gora
# Processing Record 392 of 638 | Kautokeino
# City not found. Skipping this location...
# Processing Record 393 of 638 | Najrān
# Processing Record 394 of 638 | Mayo
# Processing Record 395 of 638 | São João da Barra
# Processing Record 396 of 638 | Kumluca
# Processing Record 397 of 638 | Campos do Jordão
# Processing Record 398 of 638 | Kaeo
# Processing Record 399 of 638 | Sterling
# Processing Record 400 of 638 | Kulhudhuffushi
# Processing Record 401 of 638 | Shahrud
# Processing Record 402 of 638 | Longhua
# Processing Record 403 of 638 | Moree
# Processing Record 404 of 638 | Raudeberg
# Processing Record 405 of 638 | Mandalgovi
# Processing Record 406 of 638 | Zalari
# Processing Record 407 of 638 | Lucea
# Processing Record 408 of 638 | Kahului
# City not found. Skipping this location...
# Processing Record 409 of 638 | Angren
# Processing Record 410 of 638 | Birao
# Processing Record 411 of 638 | Dosso
# City not found. Skipping this location...
# Processing Record 412 of 638 | Dhanera
# Processing Record 413 of 638 | Orhangazi
# Processing Record 414 of 638 | Akālgarh
# Processing Record 415 of 638 | São Raimundo das Mangabeiras
# City not found. Skipping this location...
# City not found. Skipping this location...
# Processing Record 416 of 638 | Black River
# Processing Record 417 of 638 | Irtyshskiy
# Processing Record 418 of 638 | Curup
# Processing Record 419 of 638 | Mercedes
# Processing Record 420 of 638 | Tomatlán
# Processing Record 421 of 638 | Ishigaki
# Processing Record 422 of 638 | Dunmore
# City not found. Skipping this location...
# Processing Record 423 of 638 | Santa Maria
# Processing Record 424 of 638 | Viedma
# Processing Record 425 of 638 | Dhidhdhoo
# Processing Record 426 of 638 | Grand Gaube
# Processing Record 427 of 638 | Santa Fe
# Processing Record 428 of 638 | Coyhaique
# Processing Record 429 of 638 | Manokwari
# City not found. Skipping this location...
# Processing Record 430 of 638 | Zile
# Processing Record 431 of 638 | Taywarah
# Processing Record 432 of 638 | Kupang
# Processing Record 433 of 638 | Changping
# Processing Record 434 of 638 | Opuwo
# Processing Record 435 of 638 | Madimba
# City not found. Skipping this location...
# Processing Record 436 of 638 | Longkou
# Processing Record 437 of 638 | Camopi
# Processing Record 438 of 638 | Souillac
# Processing Record 439 of 638 | Saint-Pierre
# Processing Record 440 of 638 | Naze
# Processing Record 441 of 638 | Bangkalan
# Processing Record 442 of 638 | Oranjemund
# Processing Record 443 of 638 | Baraguá
# Processing Record 444 of 638 | Sarakhs
# Processing Record 445 of 638 | Cairns
# Processing Record 446 of 638 | Kretinga
# Processing Record 447 of 638 | Ternate
# Processing Record 448 of 638 | Sabha
# Processing Record 449 of 638 | Darnah
# Processing Record 450 of 638 | Ibrā’
# Processing Record 451 of 638 | Saint-Philippe
# Processing Record 452 of 638 | Eenhana
# Processing Record 453 of 638 | Noumea
# Processing Record 454 of 638 | Cedar City
# Processing Record 455 of 638 | Indramayu
# Processing Record 456 of 638 | Gallup
# Processing Record 457 of 638 | Homer
# Processing Record 458 of 638 | Fuente Palmera
# Processing Record 459 of 638 | Gaogou
# Processing Record 460 of 638 | Broome
# Processing Record 461 of 638 | Astoria
# Processing Record 462 of 638 | Abnūb
# Processing Record 463 of 638 | Puerto Escondido
# Processing Record 464 of 638 | Oussouye
# Processing Record 465 of 638 | Porto-Novo
# Processing Record 466 of 638 | Necochea
# Processing Record 467 of 638 | Koulikoro
# Processing Record 468 of 638 | Bukama
# Processing Record 469 of 638 | Bend
# Processing Record 470 of 638 | Ballina
# Processing Record 471 of 638 | San Miguel
# Processing Record 472 of 638 | Tura
# Processing Record 473 of 638 | Avera
# Processing Record 474 of 638 | Lompoc
# Processing Record 475 of 638 | Strezhevoy
# Processing Record 476 of 638 | Kargopol'
# Processing Record 477 of 638 | Portland
# Processing Record 478 of 638 | Mvuma
# Processing Record 479 of 638 | Fukuechō
# Processing Record 480 of 638 | Neiafu
# Processing Record 481 of 638 | Sioux Lookout
# Processing Record 482 of 638 | Trairi
# Processing Record 483 of 638 | Geraldton
# Processing Record 484 of 638 | Saint-François
# Processing Record 485 of 638 | Panguna
# Processing Record 486 of 638 | La Macarena
# Processing Record 487 of 638 | Waingapu
# Processing Record 488 of 638 | Goba
# Processing Record 489 of 638 | Pathein
# City not found. Skipping this location...
# Processing Record 490 of 638 | Ambulu
# Processing Record 491 of 638 | Arvika
# Processing Record 492 of 638 | Gaoual
# Processing Record 493 of 638 | Pecos
# Processing Record 494 of 638 | Norman Wells
# Processing Record 495 of 638 | Praia da Vitória
# Processing Record 496 of 638 | Berlevåg
# City not found. Skipping this location...
# Processing Record 497 of 638 | Rawson
# Processing Record 498 of 638 | Le Port
# Processing Record 499 of 638 | Sri Aman
# Processing Record 500 of 638 | Caraballeda
# Processing Record 501 of 638 | Bergen
# Processing Record 502 of 638 | Naftalan
# Processing Record 503 of 638 | Anadyr
# Processing Record 504 of 638 | Lüneburg
# Processing Record 505 of 638 | Terrace Bay
# City not found. Skipping this location...
# Processing Record 506 of 638 | Mount Isa
# Processing Record 507 of 638 | Saint-Joseph
# Processing Record 508 of 638 | Camargo
# Processing Record 509 of 638 | Sucúa
# Processing Record 510 of 638 | Abhā
# Processing Record 511 of 638 | Tumaco
# City not found. Skipping this location...
# Processing Record 512 of 638 | Deputatsky
# Processing Record 513 of 638 | Cidreira
# Processing Record 514 of 638 | Margate
# Processing Record 515 of 638 | Diamantino
# Processing Record 516 of 638 | Dunyapur
# Processing Record 517 of 638 | Telêmaco Borba
# Processing Record 518 of 638 | Pitimbu
# Processing Record 519 of 638 | Levice
# Processing Record 520 of 638 | Vila Praia de Âncora
# Processing Record 521 of 638 | Kholtoson
# City not found. Skipping this location...
# Processing Record 522 of 638 | Shubarshi
# Processing Record 523 of 638 | Aasiaat
# Processing Record 524 of 638 | Valea Argovei
# Processing Record 525 of 638 | Kabalo
# Processing Record 526 of 638 | Contamana
# Processing Record 527 of 638 | College
# Processing Record 528 of 638 | Tessalit
# Processing Record 529 of 638 | Mbaïki
# Processing Record 530 of 638 | Phang Nga
# Processing Record 531 of 638 | Ankpa
# Processing Record 532 of 638 | Camacha
# City not found. Skipping this location...
# Processing Record 533 of 638 | Canguaretama
# Processing Record 534 of 638 | Gawler
# Processing Record 535 of 638 | Nabire
# Processing Record 536 of 638 | Abbeville
# Processing Record 537 of 638 | Teya
# Processing Record 538 of 638 | Buin
# City not found. Skipping this location...
# Processing Record 539 of 638 | Tevaitoa
# Processing Record 540 of 638 | Esso
# Processing Record 541 of 638 | Qaqortoq
# Processing Record 542 of 638 | Mogadishu
# Processing Record 543 of 638 | Omboué
# Processing Record 544 of 638 | Kavaratti
# Processing Record 545 of 638 | Chardara
# Processing Record 546 of 638 | Los Llanos de Aridane
# Processing Record 547 of 638 | Ugoofaaru
# City not found. Skipping this location...
# Processing Record 548 of 638 | San Vicente
# Processing Record 549 of 638 | San Patricio
# Processing Record 550 of 638 | Melita
# Processing Record 551 of 638 | Can Tho
# Processing Record 552 of 638 | Yamada
# Processing Record 553 of 638 | Etchoropo
# City not found. Skipping this location...
# Processing Record 554 of 638 | Carauari
# Processing Record 555 of 638 | Port Hedland
# Processing Record 556 of 638 | Muroto-misakicho
# Processing Record 557 of 638 | Pucara
# Processing Record 558 of 638 | Port-Gentil
# Processing Record 559 of 638 | Tūkrah
# Processing Record 560 of 638 | Båtsfjord
# Processing Record 561 of 638 | Araçoiaba da Serra
# Processing Record 562 of 638 | Saquena
# Processing Record 563 of 638 | Nkongsamba
# Processing Record 564 of 638 | Kazanskoye
# Processing Record 565 of 638 | Coari
# Processing Record 566 of 638 | Imeni Babushkina
# Processing Record 567 of 638 | Nouadhibou
# Processing Record 568 of 638 | Buala
# Processing Record 569 of 638 | Ereymentau
# City not found. Skipping this location...
# Processing Record 570 of 638 | Mareeba
# Processing Record 571 of 638 | Kungurtug
# Processing Record 572 of 638 | Tongren
# Processing Record 573 of 638 | Innisfail
# Processing Record 574 of 638 | Oranjestad
# Processing Record 575 of 638 | Touros
# Processing Record 576 of 638 | Aykhal
# Processing Record 577 of 638 | Kuppam
# Processing Record 578 of 638 | San Felipe
# Processing Record 579 of 638 | Mitú
# Processing Record 580 of 638 | Krasnoarmiys'k

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data=pd.DataFrame({"City":city_name,
                        "Cloudiness":clouds,
                        "Country":country,
                        "Date":date,
                        "Humidity":humidity,
                        "Lat":latitude,
                        "Lng":longitude,
                        "Max Temp":max_temp,
                        "Wind Speed":wind_speed})
city_data
# Out:
#                City  Cloudiness Country        Date  Humidity      Lat  \
# 0      Puerto Ayora          96      EC  1618627476        97  -0.7393
# 1              Atar           0      MR  1618627476        29  20.5169
# 2          Coquimbo          90      CL  1618627396        88 -29.9533
# 3         Carnarvon           1      AU  1618627477        39 -24.8667
# 4          Lüderitz          92      NA  1618627477        33 -26.6481
# ..              ...         ...     ...         ...       ...      ...
# 575          Aykhal         100      RU  1618627666        90  66.0000
# 576          Kuppam           5      IN  1618627666        62  12.7500
# 577      San Felipe          92      VE  1618627666        96  10.3399
# 578            Mitú         100      CO  1618627667        98   1.1983
# 579  Krasnoarmiys'k          12      UA  1618627469        91  48.2820
#
#           Lng  Max Temp  Wind Speed
# 0    -90.3518     75.99        4.00
# 1    -13.0499     71.62        9.69
# 2    -71.3436     59.00        8.05
# 3    113.6333     82.92        6.42
# 4     15.1594     78.31       11.83
# ..        ...       ...         ...
# 575  111.5000      8.78       21.36
# 576   78.3667     79.20        3.31
# 577  -68.7425     73.08        3.00
# 578  -70.1733     72.46        1.90
# 579   37.1758     37.26        5.88
#
# [580 rows x 9 columns]

# %%
city_data["Humidity"].max()
# Out:
# 100

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data.count()
# Out:
# City          580
# Cloudiness    580
# Country       580
# Date          580
# Humidity      580
# Lat           580
# Lng           580
# Max Temp      580
# Wind Speed    580
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
#convert unix timestamp to date time - pandas.pydata.org time series/date functionality
city_data["Date"]=pd.to_datetime(city_data["Date"],unit="s")
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=city_data[["City","Lat","Lng","Max Temp","Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]]
clean_sort=clean_city_data.sort_values(by='City',ascending=True).reset_index(drop=True)
clean_sort
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Aasiaat  68.7098  -52.8699      3.60        85         100
# 1       Abbeville  50.1000    1.8333     28.99        83          11
# 2            Abhā  18.2164   42.5053     60.80        27           0
# 3           Abnūb  27.2696   31.1511     68.00        37           0
# 4        Acajutla  13.5928  -89.8275     72.00        93          99
# ..            ...      ...       ...       ...       ...         ...
# 575      Zhigansk  66.7697  123.3711     21.43        76         100
# 576          Zile  40.3031   35.8864     44.60        87          75
# 577  Örnsköldsvik  63.2909   18.7153     32.00        86          72
# 578         Āsosa  10.0667   34.5333     69.39        15          23
# 579       Łęczyca  52.0596   19.1997     39.99        95         100
#
#      Wind Speed Country                Date
# 0         10.78      GL 2021-04-17 02:45:42
# 1          5.61      FR 2021-04-17 02:47:31
# 2          5.53      SA 2021-04-17 02:47:23
# 3         11.50      EG 2021-04-17 02:47:06
# 4          1.99      SV 2021-04-17 02:45:26
# ..          ...     ...                 ...
# 575       19.01      RU 2021-04-17 02:44:42
# 576        4.61      TR 2021-04-17 02:46:52
# 577        5.75      SE 2021-04-17 02:45:29
# 578        4.09      ET 2021-04-17 02:46:09
# 579        3.00      PL 2021-04-17 02:46:32
#
# [580 rows x 9 columns]

# %%
clean_sort=clean_sort.rename(columns={"Max Temp":"Max Temp ˚F"})
clean_sort
clean_sort.to_csv('output_data/cities.csv',index=True,header=True)
datadate=((clean_sort.iloc[0,8]))
chartdate=(datadate.strftime("%b %d, %Y"))

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Max Temp ˚F"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Max. Temperature "+"("+chartdate+")")
plt.ylabel("Max. Temperature (˚F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvsmaxtemp.png")
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Humidity"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Humidity (%)  "+"("+chartdate+")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvshumidity.png")
plt.savefig("output_data/Fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Cloudiness"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Cloudiness (%) "+"("+chartdate+")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvscloud.png")
plt.savefig("output_data/Fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_sort["Lat"],clean_sort["Wind Speed"], marker="o", facecolors="lightblue", edgecolors="black",)
plt.title("City Latitude vs. Wind Speed  "+"("+chartdate+")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/citylatvsmaxtemp.png")
plt.savefig("output_data/Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northhem=clean_sort[clean_sort['Lat']>=0]
southhem=clean_sort[clean_sort['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northhem['Lat']
y_values = northhem['Max Temp ˚F']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Latitude vs. Max. Temperature  "+"("+chartdate+")")
plt.ylabel("Max. Temperature (˚F)")
plt.xlabel("Latitude")
plt.grid()
rsqrd=round((rvalue**2),2)
rsqrdstr="$R^2$= "+ str(rsqrd)
rsqrdstr
plt.text(6,0,rsqrdstr,fontsize=15,color="red")
print(f"The r-squared is: {rsqrd}")
plt.savefig("output_data/citynorthlatvsmaxtemp.png")
plt.savefig("output_data/Fig5.png")
plt.show()
# Out:
# The r-squared is: 0.77

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Max Temp ˚F']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-26,50),fontsize=15,color="red")
plt.title("Southern Latitude vs. Max. Temperature  "+"("+chartdate+")")
plt.ylabel("Max. Temperature (˚F)")
plt.xlabel("Latitude")
plt.grid()
rsqrd=round((rvalue**2),2)
rsqrdstr="$R^2$= "+ str(rsqrd)
rsqrdstr
plt.text(-26,55,rsqrdstr,fontsize=15,color="red")
print(f"The r-squared is: {rsqrd}")
plt.savefig("output_data/citynorthlatvsmaxtemp.png")
plt.savefig("output_data/Fig6.png")
plt.show()
# Out:
# The r-squared is: 0.45

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northhem['Lat']
y_values = northhem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,5),fontsize=15,color="red")
plt.title("Northern Latitudes vs. Humidity (%) "+"("+chartdate+")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
rsqrd=round((rvalue**2),2)
rsqrdstr="$R^2$= "+ str(rsqrd)
rsqrdstr
plt.text(50,12,rsqrdstr,fontsize=15,color="red")
print(f"The r-squared is: {rsqrd}")
plt.savefig("output_data/northlatvshumidity.png")
plt.savefig("output_data/Fig7.png")
plt.show()
# Out:
# The r-squared is: 0.02

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.title("Southern Latitudes vs. Humidity (%) "+"("+chartdate+")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
rsqrd=round((rvalue**2),2)
rsqrdstr="$R^2$= "+ str(rsqrd)
rsqrdstr
plt.text(-50,28,rsqrdstr,fontsize=15,color="red")
print(f"The r-squared is: {rsqrd}")
plt.savefig("output_data/southlatvshumidity.png")
plt.savefig("output_data/Fig8.png")
plt.show()
# Out:
# The r-squared is: 0.07

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northhem['Lat']
y_values = northhem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,45),fontsize=15,color="red")
plt.title("Northern Latitudes vs. Cloudiness (%) "+"("+chartdate+")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
rsqrd=round((rvalue**2),2)
rsqrdstr="$R^2$= "+ str(rsqrd)
rsqrdstr
plt.text(50,55,rsqrdstr,fontsize=15,color="red")
print(f"The r-squared is: {rsqrd}")
plt.savefig("output_data/northlatvscloudiness.png")
plt.savefig("output_data/Fig9.png")
plt.show()
# Out:
# The r-squared is: 0.01

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,45),fontsize=15,color="red")
plt.title("Southern Latitudes vs. Cloudiness (%) "+"("+chartdate+")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
rsqrd=round((rvalue**2),2)
rsqrdstr="$R^2$= "+ str(rsqrd)
rsqrdstr
plt.text(-50,55,rsqrdstr,fontsize=15,color="red")
print(f"The r-squared is: {rsqrd}")
plt.savefig("output_data/southlatvscloudiness.png")
plt.savefig("output_data/Fig10.png")
plt.show()
# Out:
# The r-squared is: 0.06

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northhem['Lat']
y_values = northhem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,25),fontsize=15,color="red")
plt.title("Northern Latitudes vs. Windspeed (%) "+"("+chartdate+")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
rsqrd=round((rvalue**2),2)
rsqrdstr="$R^2$= "+ str(rsqrd)
rsqrdstr
plt.text(0,30,rsqrdstr,fontsize=15,color="red")
print(f"The r-squared is: {rsqrd}")
plt.savefig("output_data/northlatvsWindspeed.png")
plt.savefig("output_data/Fig11.png")
plt.show()
# Out:
# The r-squared is: 0.06

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black",)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,13),fontsize=15,color="red")
plt.title("Southern Latitudes vs. Windspeed (%) "+"("+chartdate+")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
rsqrd=round((rvalue**2),2)
rsqrdstr="$R^2$= "+ str(rsqrd)
rsqrdstr
plt.text(-55,15,rsqrdstr,fontsize=15,color="red")
print(f"The r-squared is: {rsqrd}")
plt.savefig("output_data/southlatvsWindspeed.png")
plt.savefig("output_data/Fig12.png")
plt.show()
# Out:
# The r-squared is: 0.04

# %%
#Create one single image with multiple plots

# %%
from PIL import Image
im1=Image.open("output_data/fig1.png")
im2=Image.open("output_data/fig2.png")
def get_concat_h(im1, im2):
    dst = Image.new('RGB', (im1.width + im2.width, im1.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    return dst
get_concat_h(im1, im2).save('output_data/Fig13.jpg')

# %%
im3=Image.open("output_data/fig3.png")
im4=Image.open("output_data/fig4.png")
def get_concat_h(im3, im4):
    dst = Image.new('RGB', (im3.width + im4.width, im3.height))
    dst.paste(im3, (0, 0))
    dst.paste(im4, (im3.width, 0))
    return dst
get_concat_h(im3, im4).save('output_data/Fig14.jpg')

# %%
im5=Image.open("output_data/fig5.png")
im6=Image.open("output_data/fig6.png")
def get_concat_h(im5, im6):
    dst = Image.new('RGB', (im5.width + im6.width, im5.height))
    dst.paste(im5, (0, 0))
    dst.paste(im6, (im5.width, 0))
    return dst
get_concat_h(im5, im6).save('output_data/Fig15.jpg')

# %% [markdown]
# ![fig15.jpg](attachment:fig15.jpg)

# %%
im7=Image.open("output_data/fig7.png")
im8=Image.open("output_data/fig8.png")
def get_concat_h(im7, im8):
    dst = Image.new('RGB', (im7.width + im8.width, im7.height))
    dst.paste(im7, (0, 0))
    dst.paste(im8, (im7.width, 0))
    return dst
get_concat_h(im7, im8).save('output_data/Fig16.jpg')

# %% [markdown]
# ![fig16.jpg](attachment:fig16.jpg)

# %%
im9=Image.open("output_data/fig9.png")
im10=Image.open("output_data/fig10.png")
def get_concat_h(im9, im10):
    dst = Image.new('RGB', (im9.width + im10.width, im9.height))
    dst.paste(im9, (0, 0))
    dst.paste(im10, (im9.width, 0))
    return dst
get_concat_h(im9, im10).save('output_data/Fig17.jpg')

# %% [markdown]
# ![fig17.jpg](attachment:fig17.jpg)

# %%
im11=Image.open("output_data/fig11.png")
im12=Image.open("output_data/fig12.png")
def get_concat_h(im11, im12):
    dst = Image.new('RGB', (im11.width + im12.width, im11.height))
    dst.paste(im11, (0, 0))
    dst.paste(im12, (im11.width, 0))
    return dst
get_concat_h(im11, im12).save('output_data/Fig18.jpg')

# %% [markdown]
# ![fig18.jpg](attachment:fig18.jpg)

# %%
im13=Image.open("output_data/fig13.jpg")
im14=Image.open("output_data/fig14.jpg")
def get_concat_h(im13, im14):
    dst = Image.new('RGB', (im13.width + im14.width, im13.height))
    dst.paste(im13, (0, 0))
    dst.paste(im14, (im13.width, 0))
    return dst
get_concat_h(im13, im14).save('output_data/Fig19.jpg')

# %%
im15=Image.open("output_data/fig15.jpg")
im16=Image.open("output_data/fig16.jpg")
def get_concat_h(im15, im16):
    dst = Image.new('RGB', (im15.width + im16.width, im15.height))
    dst.paste(im15, (0, 0))
    dst.paste(im16, (im15.width, 0))
    return dst
get_concat_h(im15, im16).save('output_data/Fig20.jpg')

# %%
im17=Image.open("output_data/fig17.jpg")
im18=Image.open("output_data/fig18.jpg")
def get_concat_h(im17, im18):
    dst = Image.new('RGB', (im17.width + im18.width, im17.height))
    dst.paste(im17, (0, 0))
    dst.paste(im18, (im17.width, 0))
    return dst
get_concat_h(im17, im18).save('output_data/Fig21.jpg')

# %%
im19=Image.open("output_data/fig19.jpg")
im20=Image.open("output_data/fig20.jpg")
def get_concat_v(im19, im20):
    dst = Image.new('RGB', (im19.width, im19.height + im20.height))
    dst.paste(im19, (0, 0))
    dst.paste(im20, (0, im19.height))
    return dst

get_concat_v(im19, im20).save('output_data/Fig22.jpg')

# %%
im21=Image.open("output_data/fig21.jpg")
im22=Image.open("output_data/fig22.jpg")
def get_concat_v(im22, im21):
    dst = Image.new('RGB', (im22.width, im22.height + im21.height))
    dst.paste(im22, (0, 0))
    dst.paste(im21, (0, im22.height))
    return dst

get_concat_v(im22, im21).save('output_data/Fig23.jpg')

# %% [markdown]
# # Final Composit of graphs

# %% [markdown]
# ![fig23.jpg](attachment:fig23.jpg)
